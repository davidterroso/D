# %% [markdown]
# # U-Net Runs

# %% [markdown]
# **Warning**: The results obtained below were obtained using an older version of the [patch_extraction.py](init/patch_extraction.py) file, available [here](https://github.com/davidterroso/D/blob/3f3c8e8b74bb716c6c772508a888035e631da6a5/init/patch_extraction.py).

# %% [markdown]
# ## Table of Contents
# * [Iteration 1](#iteration1)
# * [Iteration 2](#iteration2)
# * [Iteration 3](#iteration3)

# %% [markdown]
# ## Iteration 1 <a id="iteration1"></a>

# %% [markdown]
# *Run 001*
# - Train Folds: 3, 4, 5
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %%
split="competitive_fold_selection.csv"

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run001",
    model_name="UNet",
    device="GPU",
    split=split,
    epochs=100,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="small",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %% [markdown]
# To check the log files, please check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/logs).

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_random_imgs", run_name="Run001")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet",
    weights_name="Run001_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="small",
    save_images=False
)

# %% [markdown]
# Show Test Results

# %% [markdown]
# To see the result files check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/results).

# %%
from pandas import read_csv

class_df = read_csv("results\\Run001_class_dice.csv")
class_df
# Out:
#                                    dice_IRF  \
# 0  0.20018861094938237 (0.3351390397629508)
#
#                                    dice_SRF  \
# 0  0.2535202226015469 (0.39161685768811433)
#
#                                     dice_PED
# 0  0.08321382962013993 (0.19609977080916952)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run001_vendor_dice.csv")
vendor_df
# Out:
#        Vendor                                   dice_IRF  \
# 0      Cirrus  0.13790561717905803 (0.27258035412643755)
# 1  Spectralis    0.2553363329597882 (0.3128986059517363)
# 2      Topcon   0.25900540586111936 (0.4053984932697679)
#
#                                    dice_SRF  \
# 0   0.0893619497539703 (0.1868576687258789)
# 1  0.3309156417390522 (0.42303996320283677)
# 2  0.44570642111440456 (0.4801217577793645)
#
#                                     dice_PED
# 0  0.07221309865476541 (0.15731577883609182)
# 1   0.1625890921421197 (0.31320886318642055)
# 2  0.05552081287896726 (0.14583791252152178)

# %% [markdown]
# *Run 002*
# - Train Folds: 2, 4, 5
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run002",
    model_name="UNet",
    device="GPU",
    split=split,
    epochs=100,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="small",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %% [markdown]
# To check the log files, please check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/logs).

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_random_imgs", run_name="Run002")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet",
    weights_name="Run002_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="small",
    save_images=False
)

# %% [markdown]
# Show Test Results

# %% [markdown]
# To see the result files check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/results).

# %%
from pandas import read_csv

class_df = read_csv("results\\Run002_class_dice.csv")
class_df
# Out:
#                                   dice_IRF  \
# 0  0.2523515718597745 (0.3791604181032975)
#
#                                    dice_SRF  \
# 0  0.4452807571053633 (0.45728131656300697)
#
#                                   dice_PED
# 0  0.326568521217909 (0.41564491253340513)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run002_vendor_dice.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus  0.13819540823824356 (0.2693905619618806)
# 1  Spectralis  0.26447327649220825 (0.3616953802526951)
# 2      Topcon   0.3892463513184339 (0.4520607654098388)
#
#                                    dice_SRF  \
# 0  0.28991068160976285 (0.3926120780305019)
# 1  0.6696892814976828 (0.44162606106007785)
# 2   0.5321103661699453 (0.4726951903077954)
#
#                                     dice_PED
# 0  0.23606455548724625 (0.38203558432676193)
# 1   0.6520995727303077 (0.41857947689198866)
# 2     0.2839267838098749 (0.378027155133129)

# %% [markdown]
# *Run 003*
# - Train Folds: 2, 3, 5
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run003",
    model_name="UNet",
    device="GPU",
    split=split,
    epochs=100,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="small",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %% [markdown]
# To check the log files, please check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/logs).

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_random_imgs", run_name="Run003")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet",
    weights_name="Run003_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="small",
    save_images=False
)

# %% [markdown]
# Show Test Results

# %% [markdown]
# To see the result files check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/results).

# %%
from pandas import read_csv

class_df = read_csv("results\\Run003_class_dice.csv")
class_df
# Out:
#                                     dice_IRF  \
# 0  0.24852202878180457 (0.38622785513822844)
#
#                                    dice_SRF  \
# 0  0.38625354831549275 (0.4624468696833291)
#
#                                    dice_PED
# 0  0.11711645064250659 (0.2410020636200038)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run003_vendor_dice.csv")
vendor_df
# Out:
#        Vendor                                   dice_IRF  \
# 0      Cirrus  0.20929440171385066 (0.34266655718676126)
# 1  Spectralis     0.25459177176259 (0.32677707757506147)
# 2      Topcon   0.28589079706189297 (0.4374640867588147)
#
#                                     dice_SRF  \
# 0  0.15759972602354538 (0.35728229677593865)
# 1   0.45126133670612256 (0.4656862266656172)
# 2      0.5949987354128098 (0.45001339391128)
#
#                                      dice_PED
# 0  0.024136781110337326 (0.08129759891023769)
# 1       0.3104621312980141 (0.35883883548256)
# 2   0.15088400547392666 (0.25864908872162506)

# %% [markdown]
# *Run 004*
# - Train Folds: 2, 3, 4
# - Validation Fold: 5
# - Test Fold: 5
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run004",
    model_name="UNet",
    device="GPU",
    split=split,
    epochs=100,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="small",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %% [markdown]
# To check the log files, please check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/logs).

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_random_imgs", run_name="Run004")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet",
    weights_name="Run004_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="small",
    save_images=False
)

# %% [markdown]
# Show Test Results

# %% [markdown]
# To see the result files check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/results).

# %%
from pandas import read_csv

class_df = read_csv("results\\Run004_class_dice.csv")
class_df
# Out:
#                                   dice_IRF  \
# 0  0.2658779697896714 (0.3746095592790071)
#
#                                   dice_SRF  \
# 0  0.2798860930383029 (0.4170450998591022)
#
#                                     dice_PED
# 0  0.08051480860831035 (0.21959987543736503)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run004_vendor_dice.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus  0.16561150228517363 (0.2785626707513299)
# 1  Spectralis   0.3071822164618239 (0.3435247087401406)
# 2      Topcon   0.3714463267588144 (0.4532269073954749)
#
#                                     dice_SRF  \
# 0   0.1790121210658981 (0.33616110611911915)
# 1    0.3434776094799139 (0.4251788447888454)
# 2  0.37554902376905375 (0.47293394721074833)
#
#                                      dice_PED
# 0   0.04126192534367874 (0.13166686984895484)
# 1   0.24296464469968057 (0.37128195492427696)
# 2  0.051846127840690315 (0.16981121814650213)

# %% [markdown]
# Compare Folds Results

# %% [markdown]
# To see the result files check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/results).

# %%
from test_model import folds_results

folds_results(first_run_name="Run001", iteration=1, k=5)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration1_vendors_results.csv")
vendor_df
# Out:
#       vendors     dice_IRF     dice_SRF     dice_PED
# 0      Cirrus  0.16 (0.03)  0.18 (0.07)  0.09 (0.08)
# 1  Spectralis  0.27 (0.02)  0.45 (0.14)  0.34 (0.19)
# 2      Topcon  0.33 (0.06)  0.49 (0.08)  0.14 (0.09)

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration1_classes_results.csv")
class_df
# Out:
#       dice_IRF     dice_SRF     dice_PED
# 0  0.24 (0.02)  0.34 (0.08)  0.15 (0.10)

# %% [markdown]
# ## Iteration 2 <a id="iteration2"></a>
# - U-Net
# - 100 Epochs
# - Repetition of Iteration 1 to check the effect of random patch extraction

# %% [markdown]
# *Run 005*
# - Train Folds: 3, 4, 5
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run005",
    model_name="UNet",
    device="GPU",
    split=split,
    epochs=100,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="small",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %% [markdown]
# To check the log files, please check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/logs).

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_random_imgs", run_name="Run005")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet",
    weights_name="Run005_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="small",
    save_images=False
)

# %% [markdown]
# Show Test Results

# %% [markdown]
# To see the result files check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/results).

# %%
from pandas import read_csv

class_df = read_csv("results\\Run005_class_dice.csv")
class_df
# Out:
#                                    dice_IRF  \
# 0  0.24950102022524143 (0.3749246501459315)
#
#                                    dice_SRF  \
# 0  0.2962223115775019 (0.41941943878853283)
#
#                                     dice_PED
# 0  0.11008494891464188 (0.24853845999774116)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run005_vendor_dice.csv")
vendor_df
# Out:
#        Vendor                                   dice_IRF  \
# 0      Cirrus  0.10561220634335769 (0.22808667285267156)
# 1  Spectralis  0.28976585627818596 (0.33940782890881854)
# 2      Topcon   0.4330366364114785 (0.46618826103787403)
#
#                                    dice_SRF  \
# 0  0.15188663833432656 (0.2942936659857586)
# 1  0.40553196355396387 (0.4530177486609886)
# 2   0.4426374145716961 (0.4801039559888637)
#
#                                     dice_PED
# 0  0.08545956149482663 (0.19699518484160644)
# 1   0.25624053283613557 (0.3958023351444341)
# 2   0.06533523884302538 (0.1688095622589929)

# %% [markdown]
# *Run 006*
# - Train Folds: 2, 4, 5
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run006",
    model_name="UNet",
    device="GPU",
    split=split,
    epochs=100,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="small",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %% [markdown]
# To check the log files, please check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/logs).

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_random_imgs", run_name="Run006")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet",
    weights_name="Run006_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="small",
    save_images=False
)

# %% [markdown]
# Show Test Results

# %% [markdown]
# To see the result files check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/results).

# %%
from pandas import read_csv

class_df = read_csv("results\\Run006_class_dice.csv")
class_df
# Out:
#                                    dice_IRF  \
# 0  0.3165497498578764 (0.42895736013901425)
#
#                                   dice_SRF  \
# 0  0.565640845075023 (0.46010978012300946)
#
#                                  dice_PED
# 0  0.572155091392227 (0.4489857021975644)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run006_vendor_dice.csv")
vendor_df
# Out:
#        Vendor                                   dice_IRF  \
# 0      Cirrus   0.37038961003039506 (0.4609654392177014)
# 1  Spectralis    0.4098824906410003 (0.4272497721326835)
# 2      Topcon  0.20458874985342845 (0.35977224671317926)
#
#                                     dice_SRF  \
# 0  0.29654688737282414 (0.39616170220900077)
# 1   0.7346816494756815 (0.42035917377113324)
# 2    0.8211196260344877 (0.3576667358648054)
#
#                                   dice_PED
# 0   0.4539011906235828 (0.467938207943908)
# 1  0.6728155836843106 (0.4120205780386223)
# 2   0.6718048489710782 (0.404378190057948)

# %% [markdown]
# *Run 007*
# - Train Folds: 2, 3, 5
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run007",
    model_name="UNet",
    device="GPU",
    split=split,
    epochs=100,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False,
    patch_type="small",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %% [markdown]
# To check the log files, please check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/logs).

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_random_imgs", run_name="Run007")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet",
    weights_name="Run007_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="small",
    save_images=False
)

# %% [markdown]
# Show Test Results

# %% [markdown]
# To see the result files check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/results).

# %%
from pandas import read_csv

class_df = read_csv("results\\Run007_class_dice.csv")
class_df
# Out:
#                                   dice_IRF  \
# 0  0.5930165650040986 (0.4379947781819339)
#
#                                    dice_SRF  \
# 0  0.46031658287889826 (0.4729332307083391)
#
#                                   dice_PED
# 0  0.5958043047467367 (0.4399329884752024)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run007_vendor_dice.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus   0.5903312392707448 (0.4400965609578244)
# 1  Spectralis  0.29551784276049964 (0.3575843794184002)
# 2      Topcon  0.6868108744245547 (0.41731396607845095)
#
#                                    dice_SRF  \
# 0  0.2651205946125629 (0.43246045722216403)
# 1    0.371563870687874 (0.4564655370047387)
# 2  0.6826930892537348 (0.41901589560425706)
#
#                                     dice_PED
# 0   0.6660728849994484 (0.44361103553433545)
# 1  0.49815524325050337 (0.40633964293673575)
# 2    0.5554407495772467 (0.4359709869919281)

# %% [markdown]
# *Run 008*
# - Train Folds: 2, 3, 4
# - Validation Fold: 5
# - Test Fold: 5
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run008",
    model_name="UNet",
    device="GPU",
    split=split,
    epochs=100,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="small",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %% [markdown]
# To check the log files, please check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/logs).

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_random_imgs", run_name="Run008")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet",
    weights_name="Run008_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="small",
    save_images=False
)

# %% [markdown]
# Show Test Results

# %% [markdown]
# To see the result files check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/results).

# %%
from pandas import read_csv

class_df = read_csv("results\\Run008_class_dice.csv")
class_df
# Out:
#                                     dice_IRF  \
# 0  0.35922594178572487 (0.42682546898297885)
#
#                                     dice_SRF  \
# 0  0.43246553752487343 (0.46609202020849133)
#
#                                    dice_PED
# 0  0.16815968893092384 (0.3347175503579073)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run008_vendor_dice.csv")
vendor_df
# Out:
#        Vendor                                   dice_IRF  \
# 0      Cirrus   0.32128961009466367 (0.4186771570834817)
# 1  Spectralis    0.3519373902860953 (0.3654368862269475)
# 2      Topcon  0.41013404217574134 (0.45859229385297956)
#
#                                    dice_SRF  \
# 0  0.25875576966136576 (0.3983893422056016)
# 1   0.5144110012723475 (0.4518841309573463)
# 2   0.6103905625532207 (0.4741060473238629)
#
#                                     dice_PED
# 0   0.0666684238894959 (0.19971752649264163)
# 1  0.46667124805401783 (0.45011757570620714)
# 2     0.152181324949197 (0.3218208709072797)

# %% [markdown]
# Compare Folds Results

# %% [markdown]
# To see the result files check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/results).

# %%
from test_model import folds_results

folds_results(first_run_name="Run005", iteration=2, k=5)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration2_vendors_results.csv")
vendor_df
# Out:
#       vendors     dice_IRF     dice_SRF     dice_PED
# 0      Cirrus  0.35 (0.17)  0.24 (0.05)  0.32 (0.25)
# 1  Spectralis  0.34 (0.05)  0.51 (0.14)  0.47 (0.15)
# 2      Topcon  0.43 (0.17)  0.64 (0.14)  0.36 (0.26)

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration2_classes_results.csv")
class_df
# Out:
#       dice_IRF     dice_SRF     dice_PED
# 0  0.38 (0.13)  0.44 (0.10)  0.36 (0.22)

# %% [markdown]
# ## Iteration 3 <a id="iteration3"></a>
# - U-Net
# - 200 Epochs

# %% [markdown]
# *Run 009*
# - Train Folds: 3, 4, 5
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run009",
    model_name="UNet",
    device="GPU",
    split=split,
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="small",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_random_imgs", run_name="Run009")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet",
    weights_name="Run009_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="small",
    save_images=False
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run009_class_dice.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run009_vendor_dice.csv")
vendor_df

# %% [markdown]
# *Run 010*
# - Train Folds: 2, 4, 5
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run010",
    model_name="UNet",
    device="GPU",
    split=split,
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="small",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_random_imgs", run_name="Run010")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet",
    weights_name="Run010_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="small",
    save_images=False
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run010_class_dice.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run010_vendor_dice.csv")
vendor_df

# %% [markdown]
# *Run 011*
# - Train Folds: 2, 3, 5
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run011",
    model_name="UNet",
    device="GPU",
    split=split,
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="small",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_random_imgs", run_name="Run011")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet",
    weights_name="Run011_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="small",
    save_images=False
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run011_class_dice.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run011_vendor_dice.csv")
vendor_df

# %% [markdown]
# *Run 012*
# - Train Folds: 2, 3, 4
# - Validation Fold: 5
# - Test Fold: 5
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run012",
    model_name="UNet",
    device="GPU",
    split=split,
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="small",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_random_imgs", run_name="Run012")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet",
    weights_name="Run012_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="small",
    save_images=False
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run012_class_dice.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run012_vendor_dice.csv")
vendor_df

# %% [markdown]
# Compare Folds Results

# %%
from test_model import folds_results

folds_results(first_run_name="Run009", iteration=3, k=5)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration3_vendors_results.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration3_classes_results.csv")
class_df
