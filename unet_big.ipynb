# %% [markdown]
# # U-Net Runs

# %% [markdown]
# ## Table of Contents
# * [Iteration 4](#iteration4)
# * [Iteration 5](#iteration5)

# %% [markdown]
# ## Iteration 4 <a id="iteration4"></a>

# %% [markdown]
# *Run 013*
# - Train Folds: 3, 4, 5
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run013",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=100,
    batch_size=16,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="big",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %% [markdown]
# To check the log files, please check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/logs).

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_big_imgs", run_name="Run013")

# %% [markdown]
# ![Run013 Loss Results](./unet_big_imgs/Run013_training_error.png)

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet",
    weights_name="Run013_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="big",
    save_images=False
)

# %% [markdown]
# Show Test Results

# %% [markdown]
# To see the result files check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/results).

# %%
from pandas import read_csv

class_df = read_csv("results\\Run013_class_dice.csv")
class_df
# Out:
#                                    dice_IRF  \
# 0  0.3961200987062028 (0.42207227153455545)
#
#                                   dice_SRF  \
# 0  0.5507561500475582 (0.4481535160203299)
#
#                                     dice_PED
# 0  0.40006906554362803 (0.44305380525259475)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run013_vendor_dice.csv")
vendor_df
# Out:
#        Vendor                                 dice_IRF  \
# 0      Cirrus  0.2910691150571438 (0.3855883318041583)
# 1  Spectralis  0.4717813053605508 (0.3984638416996928)
# 2      Topcon   0.5048157101014762 (0.448174436237725)
#
#                                    dice_SRF  \
# 0  0.45013780786539426 (0.4204980705280724)
# 1    0.6381149466244542 (0.440515589326941)
# 2    0.646722297001231 (0.4603026925859788)
#
#                                     dice_PED
# 0  0.28131749713938914 (0.39033261471442326)
# 1   0.39359052886768264 (0.4452675049491124)
# 2    0.5732571130086269 (0.4567669939252632)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 014*
# - Train Folds: 2, 4, 5
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run014",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=100,
    batch_size=16,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="big",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %% [markdown]
# To check the log files, please check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/logs).

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_big_imgs", run_name="Run014")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet",
    weights_name="Run014_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="big",
    save_images=False
)
# Out:
# Testing Model:   0%|          | 0/1397 [00:00<?, ?img/s]

# %% [markdown]
# Show Test Results

# %% [markdown]
# To see the result files check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/results).

# %%
from pandas import read_csv

class_df = read_csv("results\\Run014_class_dice.csv")
class_df
# Out:
#                                    dice_IRF  \
# 0  0.6272253246781928 (0.43152316498769455)
#
#                                   dice_SRF  \
# 0  0.7109327857744592 (0.4069522496020755)
#
#                                   dice_PED
# 0  0.7441746885938277 (0.3785584781572642)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run014_vendor_dice.csv")
vendor_df
# Out:
#        Vendor                                   dice_IRF  \
# 0      Cirrus    0.5858550953955273 (0.4389018414391247)
# 1  Spectralis  0.48163289629607176 (0.42960171495791366)
# 2      Topcon     0.7486063631440629 (0.390680158967197)
#
#                                    dice_SRF  \
# 0    0.6188084307068493 (0.427091528922919)
# 1  0.7803360883982814 (0.37910604775886947)
# 2   0.792877664876869 (0.36883416570246974)
#
#                                   dice_PED
# 0  0.7266909381665755 (0.4081064244168181)
# 1  0.6977675867818144 (0.3899706744717974)
# 2  0.7882358999559074 (0.3274936687816366)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 015*
# - Train Folds: 2, 3, 5
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run015",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=100,
    batch_size=16,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="big",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %% [markdown]
# To check the log files, please check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/logs).

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_big_imgs", run_name="Run015")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet",
    weights_name="Run015_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="big",
    save_images=False
)

# %% [markdown]
# Show Test Results

# %% [markdown]
# To see the result files check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/results).

# %%
from pandas import read_csv

class_df = read_csv("results\\Run015_class_dice.csv")
class_df
# Out:
#                                   dice_IRF  \
# 0  0.2780770802372552 (0.3749501197279851)
#
#                                  dice_SRF  \
# 0  0.493743292420098 (0.4716076553960805)
#
#                                    dice_PED
# 0  0.3634033465409667 (0.42180314698717286)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run015_vendor_dice.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus   0.2814077172370162 (0.3733858674134728)
# 1  Spectralis  0.4294814400336876 (0.40482926686400134)
# 2      Topcon   0.2283788580498367 (0.3543614049122622)
#
#                                     dice_SRF  \
# 0  0.45294829562772065 (0.49241089981133634)
# 1   0.5025372535598521 (0.45904833130049283)
# 2    0.5318451386134256 (0.4510848081987828)
#
#                                     dice_PED
# 0  0.41538246556738156 (0.46334612773672695)
# 1   0.3223687119791474 (0.36110139517576767)
# 2   0.32399108434910884 (0.3891365466758405)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 016*
# - Train Folds: 2, 3, 4
# - Validation Fold: 5
# - Test Fold: 5
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run016",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=100,
    batch_size=16,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="big",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %% [markdown]
# To check the log files, please check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/logs).

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_big_imgs", run_name="Run016")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet",
    weights_name="Run016_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="big",
    save_images=False
)

# %% [markdown]
# Show Test Results

# %% [markdown]
# To see the result files check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/results).

# %%
from pandas import read_csv

class_df = read_csv("results\\Run016_class_dice.csv")
class_df
# Out:
#                                    dice_IRF  \
# 0  0.32512928519475304 (0.3816966353239995)
#
#                                   dice_SRF  \
# 0  0.4876965762843673 (0.4680665461857605)
#
#                                   dice_PED
# 0  0.377492420039351 (0.44732355117380634)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run016_vendor_dice.csv")
vendor_df
# Out:
#        Vendor                                   dice_IRF  \
# 0      Cirrus     0.24180366890504956 (0.32953756148645)
# 1  Spectralis    0.5512994506225294 (0.3880264870647721)
# 2      Topcon  0.32106034749085666 (0.39634324650094394)
#
#                                    dice_SRF  \
# 0   0.3344652616651729 (0.4287436580822217)
# 1  0.5636792751874927 (0.44764257030891674)
# 2   0.6428768109035445 (0.4654776939124893)
#
#                                    dice_PED
# 0  0.3364312021934893 (0.42908870919705283)
# 1   0.4225287278695982 (0.4443537232433346)
# 2  0.40726836535759503 (0.4670737686600558)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# Compare Folds Results

# %% [markdown]
# To see the result files check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/results).

# %%
from test_model import folds_results

folds_results(first_run_name="Run013", iteration=4, k=5)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration4_vendors_results.csv")
vendor_df
# Out:
#       vendors     dice_IRF     dice_SRF     dice_PED
# 0      Cirrus  0.35 (0.14)  0.46 (0.10)  0.44 (0.17)
# 1  Spectralis  0.48 (0.04)  0.62 (0.10)  0.46 (0.14)
# 2      Topcon  0.45 (0.20)  0.65 (0.09)  0.52 (0.18)

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration4_classes_results.csv")
class_df
# Out:
#       dice_IRF     dice_SRF     dice_PED
# 0  0.41 (0.13)  0.56 (0.09)  0.47 (0.16)

# %% [markdown]
# ## Iteration 5 <a id="iteration5"></a>
# - U-Net
# - 200 Epochs

# %% [markdown]
# *Run 017*
# - Train Folds: 3, 4, 5
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run017",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=16,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="big",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_big_imgs", run_name="Run017")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet",
    weights_name="Run017_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="big",
    save_images=False
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run017_class_dice.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run017_vendor_dice.csv")
vendor_df

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 018*
# - Train Folds: 2, 4, 5
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run018",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=16,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="big",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %% [markdown]
# To check the log files, please check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/logs).

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_big_imgs", run_name="Run018")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet",
    weights_name="Run018_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="big",
    save_images=False
)

# %% [markdown]
# Show Test Results

# %% [markdown]
# To see the result files check [this commit](https://github.com/davidterroso/D/tree/9a75341e6796b5e0667ccf7f458ac99a34e01764/results).

# %%
from pandas import read_csv

class_df = read_csv("results\\Run018_class_dice.csv")
class_df
# Out:
#                                  dice_IRF  \
# 0  0.5286917486759709 (0.445379169180737)
#
#                                   dice_SRF  \
# 0  0.6678243481248094 (0.4269777161717247)
#
#                                   dice_PED
# 0  0.6618530709315131 (0.4183641754426326)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run018_vendor_dice.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus  0.46318099715608696 (0.4393788897716473)
# 1  Spectralis  0.3653271700426632 (0.40582017706554235)
# 2      Topcon  0.6887526915234048 (0.42191911560865547)
#
#                                    dice_SRF  \
# 0  0.5861119721390423 (0.43553771732328095)
# 1  0.6239599662167685 (0.45489755436033186)
# 2   0.7909546102309832 (0.3708887665286683)
#
#                                    dice_PED
# 0   0.6172035994008184 (0.4474668914031521)
# 1  0.4931870882912558 (0.43596062420285664)
# 2  0.7983742184442235 (0.31971023338975213)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 019*
# - Train Folds: 2, 3, 5
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run019",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=16,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="big",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_big_imgs", run_name="Run019")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet",
    weights_name="Run019_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="big",
    save_images=False
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run019_class_dice.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run019_vendor_dice.csv")
vendor_df

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 020*
# - Train Folds: 2, 3, 4
# - Validation Fold: 5
# - Test Fold: 5
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run020",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=16,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="big",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_big_imgs", run_name="Run020")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet",
    weights_name="Run020_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="big",
    save_images=False
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run020_class_dice.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run020_vendor_dice.csv")
vendor_df

# %% [markdown]
# Compare Folds Results

# %%
from test_model import folds_results

folds_results(first_run_name="Run017", iteration=5, k=5)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration5_vendors_results.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration5_classes_results.csv")
class_df
