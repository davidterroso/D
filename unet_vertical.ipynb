# %% [markdown]
# # U-Net Runs

# %% [markdown]
# ## Table of Contents
# * [Iteration 9](#iteration9)
# * [Iteration 10](#iteration10)
# * [Iteration 11](#iteration11)
# * [Iteration 15](#iteration15)
# * [Iteration 16](#iteration16)
# * [Iteration 17](#iteration17)
# * [Iteration 18](#iteration18)

# %% [markdown]
# ## Iteration 9 <a id="iteration9"></a>

# %% [markdown]
# *Run 023*
# - Train Folds: 3, 4, 5
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run023",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=100,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Training

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run023")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet",
    weights_name="Run023_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False
)

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet",
    weights_name="Run023_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run023_class_dice.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run023_vendor_dice.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Run023_class_dice_resized.csv")
class_df
# Out:
#                                    dice_IRF  \
# 0  0.5632453260191179 (0.43153906645583656)
#
#                                    dice_SRF  \
# 0  0.7037801500982748 (0.40669944992075896)
#
#                                    dice_PED
# 0  0.5259805403853556 (0.45740156711122837)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run023_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                   dice_IRF  \
# 0      Cirrus  0.41124616905835865 (0.43258226006528555)
# 1  Spectralis   0.6537046978972396 (0.36629460109731926)
# 2      Topcon    0.7309170098243547 (0.3852843503197536)
#
#                                    dice_SRF  \
# 0   0.6645385885145515 (0.3972229503902049)
# 1   0.735053173923979 (0.40203166801149137)
# 2  0.7427370888846261 (0.41813150432647095)
#
#                                     dice_PED
# 0  0.49807532241757146 (0.44707647610732854)
# 1   0.6113732742471145 (0.45077241746081614)
# 2   0.5191459861515406 (0.47077627116296494)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 024*
# - Train Folds: 2, 4, 5
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run024",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=100,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128),
    n_pos=12, 
    n_neg=0, 
    pos=1,
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run024")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet",
    weights_name="Run024_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False
)

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet",
    weights_name="Run024_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run024_class_dice.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run024_vendor_dice.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Run024_class_dice_resized.csv")
class_df
# Out:
#                                  dice_IRF  \
# 0  0.387920001771037 (0.4361674193216529)
#
#                                   dice_SRF  \
# 0  0.6135618307853735 (0.4416958282165418)
#
#                                    dice_PED
# 0  0.3496797693959646 (0.41874222401593586)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run024_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                   dice_IRF  \
# 0      Cirrus    0.3898845815689128 (0.4354149074537372)
# 1  Spectralis  0.40277281596268316 (0.41536978297689015)
# 2      Topcon   0.37835697335776786 (0.4472817413020772)
#
#                                    dice_SRF  \
# 0   0.5203431310248561 (0.4405408453684065)
# 1  0.5635177690155652 (0.46166180233159826)
# 2  0.7540320709813386 (0.39581060510239435)
#
#                                    dice_PED
# 0  0.21731103297206572 (0.3595587950675786)
# 1  0.42935190868221834 (0.4312997554196572)
# 2  0.4770163264001894 (0.43278238941561475)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 025*
# - Train Folds: 2, 3, 5
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run025",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=100,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run025")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet",
    weights_name="Run025_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False
)

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet",
    weights_name="Run025_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run025_class_dice.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run025_vendor_dice.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Run025_class_dice_resized.csv")
class_df
# Out:
#                                   dice_IRF  \
# 0  0.7072428602265916 (0.3848681483286403)
#
#                                    dice_SRF  \
# 0  0.8151659306598106 (0.35545180038671426)
#
#                                    dice_PED
# 0  0.7647785543953762 (0.36427810018991186)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run025_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                 dice_IRF  \
# 0      Cirrus   0.7920265026739799 (0.337663450807587)
# 1  Spectralis  0.7319997017252811 (0.3444308640260254)
# 2      Topcon  0.6148774350702297 (0.4192389728017327)
#
#                                    dice_SRF  \
# 0   0.846375042857835 (0.35057150108758905)
# 1   0.900612395788942 (0.25868833981690215)
# 2  0.7577888385159894 (0.37657609375626416)
#
#                                    dice_PED
# 0    0.883036317085498 (0.2748881601414402)
# 1  0.7327532665613963 (0.34314020350629854)
# 2  0.6563285361044109 (0.41074437343108466)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 026*
# - Train Folds: 2, 3, 4
# - Validation Fold: 5
# - Test Fold: 5
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run026",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=100,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run026")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet",
    weights_name="Run026_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False
)

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet",
    weights_name="Run026_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run026_class_dice.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run026_vendor_dice.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Run026_class_dice_resized.csv")
class_df
# Out:
#                                    dice_IRF  \
# 0  0.7946699999176824 (0.31286381390951795)
#
#                                   dice_SRF  \
# 0  0.8711726840428139 (0.2998299636032332)
#
#                                   dice_PED
# 0  0.7828923804244146 (0.3736705343311801)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run026_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus   0.8099155506817624 (0.2959394437606385)
# 1  Spectralis   0.7787520392816893 (0.3077711821690276)
# 2      Topcon  0.7832300543450401 (0.33483864138969616)
#
#                                    dice_SRF  \
# 0   0.8342691834550351 (0.3371771990457922)
# 1  0.8567834748297322 (0.29367180607939763)
# 2   0.9241875212173909 (0.2400506707259622)
#
#                                    dice_PED
# 0  0.7147711343306582 (0.41498622495884874)
# 1   0.7533334647058224 (0.3859761245309123)
# 2  0.8821883410710143 (0.28081470194201175)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# Compare Folds Results

# %%
from test_model import folds_results

folds_results(first_run_name="Run023", iteration=9, k=5)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration9_vendors_results.csv")
vendor_df
# Out:
#       vendors     dice_IRF     dice_SRF     dice_PED
# 0      Cirrus  0.66 (0.03)  0.74 (0.10)  0.70 (0.06)
# 1  Spectralis  0.66 (0.06)  0.83 (0.04)  0.72 (0.07)
# 2      Topcon  0.58 (0.11)  0.67 (0.09)  0.62 (0.11)

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration9_classes_results.csv")
class_df
# Out:
#       dice_IRF     dice_SRF     dice_PED
# 0  0.59 (0.14)  0.74 (0.14)  0.65 (0.15)

# %%
from test_model import folds_results

folds_results(first_run_name="Run023", iteration=9, k=5, resized_images=True)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration9_vendors_results_resized.csv")
vendor_df
# Out:
#       vendors     dice_IRF     dice_SRF     dice_PED
# 0      Cirrus  0.60 (0.20)  0.72 (0.13)  0.58 (0.25)
# 1  Spectralis  0.64 (0.15)  0.76 (0.13)  0.63 (0.13)
# 2      Topcon  0.63 (0.16)  0.79 (0.07)  0.63 (0.16)

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration9_classes_results_resized.csv")
class_df
# Out:
#       dice_IRF     dice_SRF     dice_PED
# 0  0.61 (0.15)  0.75 (0.10)  0.61 (0.18)

# %% [markdown]
# ## Iteration 10 <a id="iteration10"></a>
# - U-Net
# - 200 Epochs

# %% [markdown]
# *Run 027*
# - Train Folds: 3, 4, 5
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run027",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run027")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet",
    weights_name="Run027_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False
)

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet",
    weights_name="Run027_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run027_class_dice.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run027_vendor_dice.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Run027_class_dice_resized.csv")
class_df
# Out:
#                                   dice_IRF  \
# 0  0.6772042513732077 (0.4042544549780025)
#
#                                   dice_SRF  \
# 0  0.8127132915435478 (0.3394183807465131)
#
#                                   dice_PED
# 0  0.7770516534586732 (0.3652307484165613)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run027_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus   0.5223929128958844 (0.4429492138230197)
# 1  Spectralis  0.8049879481597823 (0.27428290662686783)
# 2      Topcon  0.8284815971606544 (0.31500641680445557)
#
#                                    dice_SRF  \
# 0  0.7843638437567279 (0.33681209769814247)
# 1  0.7651479635919843 (0.38975304448270554)
# 2  0.8792247913910874 (0.30229259618104304)
#
#                                    dice_PED
# 0  0.7031945443945006 (0.40085641909970426)
# 1    0.86491288457598 (0.29547578476812075)
# 2  0.8345126984973571 (0.32370066875629416)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 028*
# - Train Folds: 2, 4, 5
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run028",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run028")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet",
    weights_name="Run028_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False
)

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet",
    weights_name="Run028_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run028_class_dice.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run028_vendor_dice.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Run028_class_dice_resized.csv")
class_df
# Out:
#                                    dice_IRF  \
# 0  0.6214439020390138 (0.43604418820867497)
#
#                                   dice_SRF  \
# 0  0.7292288773604478 (0.3996400025164179)
#
#                                   dice_PED
# 0  0.6969406485317392 (0.4048776210561478)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run028_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                 dice_IRF  \
# 0      Cirrus  0.5089256085106172 (0.4484960173688314)
# 1  Spectralis    0.58972809826385 (0.4245093648254464)
# 2      Topcon  0.7772682766153594 (0.3757365443009727)
#
#                                    dice_SRF  \
# 0  0.6538541012443602 (0.42022385581209726)
# 1  0.8059014764671423 (0.35874701672233955)
# 2   0.7867583108236431 (0.3752228498465303)
#
#                                    dice_PED
# 0  0.5984245627454584 (0.45745045371739784)
# 1  0.7550312777563017 (0.35681799350997684)
# 2  0.7922884820145555 (0.32011504951950037)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 029*
# - Train Folds: 2, 3, 5
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run029",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run029")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet",
    weights_name="Run029_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False
)

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet",
    weights_name="Run029_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run029_class_dice.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run029_vendor_dice.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Run029_class_dice_resized.csv")
class_df
# Out:
#                                  dice_IRF  \
# 0  0.436021628071236 (0.4306907708518789)
#
#                                  dice_SRF  \
# 0  0.566803070741799 (0.4664812994148441)
#
#                                  dice_PED
# 0  0.4195436938592614 (0.434369446797312)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run029_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus  0.37652265330543744 (0.4231225904663384)
# 1  Spectralis  0.4778498322988043 (0.41261597460435917)
# 2      Topcon  0.4827107152923418 (0.43694716463148764)
#
#                                    dice_SRF  \
# 0  0.38686484199715776 (0.4773019028657517)
# 1   0.6235483307011274 (0.4505453012117188)
# 2  0.7293630636238959 (0.39070442907837094)
#
#                                    dice_PED
# 0  0.3975940947420895 (0.45458106573441837)
# 1   0.3975215613537905 (0.3943103365996374)
# 2  0.44823757105623374 (0.4242341233134668)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 030*
# - Train Folds: 2, 3, 4
# - Validation Fold: 5
# - Test Fold: 5
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run030",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run030")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet",
    weights_name="Run030_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False
)

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet",
    weights_name="Run030_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run030_class_dice.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run030_vendor_dice.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Run030_class_dice_resized.csv")
class_df
# Out:
#                                    dice_IRF  \
# 0  0.7345596536345321 (0.36023952830223893)
#
#                                  dice_SRF  \
# 0  0.731246826974255 (0.4154023675124839)
#
#                                   dice_PED
# 0  0.7023883400677917 (0.4214750638784202)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run030_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus  0.7528300896803557 (0.34742311427506223)
# 1  Spectralis   0.7785819087709699 (0.2985523688545039)
# 2      Topcon   0.6906562716467306 (0.3971755301622992)
#
#                                   dice_SRF  \
# 0  0.6967811080161482 (0.4301163158840664)
# 1  0.8437463702595964 (0.3069021042484495)
# 2  0.720496186404489 (0.43292850295311236)
#
#                                    dice_PED
# 0   0.6962663399492157 (0.4236632401139584)
# 1  0.7833243801686153 (0.35999639874703715)
# 2   0.6713116804021411 (0.4413721064564082)

# %% [markdown]
# Compare Folds Results

# %%
from test_model import folds_results

folds_results(first_run_name="Run027", iteration=10, k=5)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration10_vendors_results.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration10_classes_results.csv")
class_df

# %%
from test_model import folds_results

folds_results(first_run_name="Run027", iteration=10, k=5, resized_images=True)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration10_vendors_results_resized.csv")
vendor_df
# Out:
#       vendors     dice_IRF     dice_SRF     dice_PED
# 0      Cirrus  0.54 (0.14)  0.63 (0.15)  0.60 (0.12)
# 1  Spectralis  0.66 (0.14)  0.76 (0.08)  0.70 (0.18)
# 2      Topcon  0.69 (0.13)  0.78 (0.06)  0.69 (0.15)

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration10_classes_results_resized.csv")
class_df
# Out:
#       dice_IRF     dice_SRF     dice_PED
# 0  0.62 (0.11)  0.71 (0.09)  0.65 (0.14)

# %% [markdown]
# ## Iteration 11 <a id="iteration11"></a>

# %% [markdown]
# - For the best data split (used in *Run027*)
# - Using 7 (*Run031*) and 13 (*Run032*) patches to see which one is best

# %% [markdown]
# *Run 031*
# - 7 patches
# - Train Folds: 3, 4, 0
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run031",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run031")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet",
    weights_name="Run031_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run031_class_dice_resized.csv")
class_df
# Out:
#                                   dice_IRF  \
# 0  0.6851582606976316 (0.4003396064470817)
#
#                                  dice_SRF  \
# 0  0.8636865502381271 (0.294029891413052)
#
#                                   dice_PED
# 0  0.7667966072750819 (0.3776386012230921)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run031_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus  0.5555961844976991 (0.44045814130651784)
# 1  Spectralis  0.7611656603156304 (0.31789152951844457)
# 2      Topcon   0.8286803943171565 (0.3118453205309324)
#
#                                    dice_SRF  \
# 0  0.8370940529042855 (0.30091357433173566)
# 1   0.8530335228053891 (0.3168169798156768)
# 2  0.9075017065208938 (0.26530937533277316)
#
#                                   dice_PED
# 0  0.6722046321243397 (0.4182490284187161)
# 1  0.8476824584664131 (0.3244611431599985)
# 2  0.8576935504773117 (0.3045443372980845)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 032*
# - 13 patches
# - Train Folds: 3, 4, 0
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run032",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=13,
    patience_after_n=100
)

# ETA 2582m 12.0s

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run032")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet",
    weights_name="Run032_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run032_class_dice_resized.csv")
class_df
# Out:
#                                    dice_IRF  \
# 0  0.6387507144490289 (0.41930717447841437)
#
#                                    dice_SRF  \
# 0  0.8256956798269708 (0.33048978603330825)
#
#                                  dice_PED
# 0  0.717758589128657 (0.4048200676956539)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run032_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus   0.4997643593465909 (0.4440922559956782)
# 1  Spectralis  0.6716879615218055 (0.37345714489378795)
# 2      Topcon  0.8192900933167299 (0.32393735738380636)
#
#                                    dice_SRF  \
# 0    0.7622420919709839 (0.359182661165564)
# 1  0.7897941794930672 (0.37093198924782866)
# 2  0.9359772954734841 (0.21743664908309174)
#
#                                    dice_PED
# 0   0.6353642187954393 (0.4274226563201279)
# 1  0.7726487204128382 (0.38418072321323626)
# 2   0.8054467919157885 (0.3571177518999184)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# ## Iteration 15 <a id="iteration15"></a>

# %% [markdown]
# - For the worst data split (used in *Run029*)
# - Using 7 (*Run033*) and 13 (*Run034*) patches to see which one is best

# %% [markdown]
# *Run 033*
# - 7 patches
# - Train Folds: 2, 3, 0
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run033",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run033")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet",
    weights_name="Run033_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run033_class_dice_resized.csv")
class_df
# Out:
#                                   dice_IRF  \
# 0  0.7000479725767482 (0.3891853512121558)
#
#                                    dice_SRF  \
# 0  0.8218922439917196 (0.34896914139885526)
#
#                                   dice_PED
# 0  0.7706472239505026 (0.3537810369882573)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run033_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                 dice_IRF  \
# 0      Cirrus   0.7342621818999759 (0.379158598459868)
# 1  Spectralis  0.6355153803466534 (0.3920136957778572)
# 2      Topcon   0.685596869623987 (0.3953606907740509)
#
#                                    dice_SRF  \
# 0  0.8552322251955047 (0.34067163222232927)
# 1   0.8457340680214823 (0.3291696659451499)
# 2   0.7812507041788195 (0.3592190533776037)
#
#                                    dice_PED
# 0  0.8358691083500162 (0.32813899026167814)
# 1  0.6887366782531751 (0.36844633469874083)
# 2   0.7305104441707954 (0.3631451519088896)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 034*
# - 13 patches
# - Train Folds: 2, 3, 0
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run034",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=13,
    patience_after_n=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run034")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet",
    weights_name="Run034_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run034_class_dice_resized.csv")
class_df
# Out:
#                                   dice_IRF  \
# 0  0.5423310063981267 (0.4346629950682451)
#
#                                   dice_SRF  \
# 0  0.6222575453211311 (0.4585201504915579)
#
#                                   dice_PED
# 0  0.7445317681015629 (0.3727768771616455)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run034_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                   dice_IRF  \
# 0      Cirrus   0.6122407336253672 (0.43047146098739486)
# 1  Spectralis  0.45462801136380554 (0.41100403319331025)
# 2      Topcon   0.49928032140014694 (0.4360556360391358)
#
#                                    dice_SRF  \
# 0   0.6476621052017435 (0.4710786479095525)
# 1   0.6362291352481259 (0.4527539998359127)
# 2  0.5925741860253766 (0.44636211370883144)
#
#                                    dice_PED
# 0  0.8817345710936934 (0.27326743911782647)
# 1   0.5477012863990908 (0.4019574768056356)
# 2  0.6676083001308143 (0.40015272452970296)

# %% [markdown]
# ## Iteration 16 <a id="iteration16"></a>

# %% [markdown]
# *Run 051*
# - 7 patches
# - Train Folds: 3, 4, 0
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run051",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=25
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run051")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet",
    weights_name="Run051_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run051_class_dice_resized.csv")
class_df
# Out:
#                                    dice_IRF  \
# 0  0.5603896432597433 (0.43511722291107985)
#
#                                  dice_SRF  \
# 0  0.809442359582428 (0.3455814178357387)
#
#                                   dice_PED
# 0  0.7273293758262352 (0.3996268425013591)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run051_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                   dice_IRF  \
# 0      Cirrus  0.40594998908345586 (0.43299064155605255)
# 1  Spectralis    0.5953408189574066 (0.3908761139756633)
# 2      Topcon      0.76190379644478 (0.3704621314798348)
#
#                                   dice_SRF  \
# 0   0.7891260841279291 (0.338479088718252)
# 1  0.8054387569731596 (0.3614385458459788)
# 2  0.8406550804086562 (0.3452682218517054)
#
#                                    dice_PED
# 0   0.6560159348917296 (0.4230601567876491)
# 1  0.7862627561299168 (0.37447413828550785)
# 2  0.7969765276648104 (0.35977629985523957)

# %%
from pandas import read_csv

class_df = read_csv("results\\Run051_class_dice_resized_wfluid.csv")
class_df
# Out:
#                                    dice_IRF  \
# 0  0.5941305488147625 (0.23442107186861735)
#
#                                   dice_SRF  \
# 0  0.7611040296922823 (0.1836784078407314)
#
#                                   dice_PED
# 0  0.5707933033667987 (0.2591361224615153)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run051_vendor_dice_resized_wfluid.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus  0.5906177644681244 (0.24754520710234296)
# 1  Spectralis  0.6367476251863298 (0.15636671078097528)
# 2      Topcon  0.5604681487368272 (0.26582114391177825)
#
#                                    dice_SRF  \
# 0  0.7733365455642343 (0.14581166027587578)
# 1  0.8303946571653349 (0.16421986485574125)
# 2   0.6003286834897065 (0.2789619658819831)
#
#                                    dice_PED
# 0   0.5514546414575984 (0.2702715979722948)
# 1  0.7252083389295472 (0.21377816253524834)
# 2  0.5211710190936311 (0.22323048661852068)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 052*
# - 7 patches
# - Train Folds: 2, 4, 0
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run052",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=25
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run052")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet",
    weights_name="Run052_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run052_class_dice_resized.csv")
class_df
# Out:
#                                    dice_IRF  \
# 0  0.6542658251840234 (0.42332886178092655)
#
#                                    dice_SRF  \
# 0  0.7991586759921134 (0.35015550333757284)
#
#                                    dice_PED
# 0  0.6643816573405672 (0.42266328098611483)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run052_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                 dice_IRF  \
# 0      Cirrus  0.5890176394343143 (0.4380732120181689)
# 1  Spectralis   0.585983287429019 (0.4216454410064444)
# 2      Topcon   0.768500318601582 (0.3795564894152317)
#
#                                    dice_SRF  \
# 0   0.7753907570033334 (0.3524757595845172)
# 1  0.8028209923481454 (0.36156044020696015)
# 2    0.827116099128034 (0.3401134155990475)
#
#                                    dice_PED
# 0  0.5532055325053079 (0.46684894695260265)
# 1  0.7661959274500912 (0.35703247517313985)
# 2   0.7546320942892635 (0.3549893823473093)

# %%
from pandas import read_csv

class_df = read_csv("results\\Run052_class_dice_resized_wfluid.csv")
class_df
# Out:
#                                    dice_IRF  \
# 0  0.5694316084478209 (0.24260325111446512)
#
#                                    dice_SRF  \
# 0  0.7250811525032317 (0.15771343653905626)
#
#                                   dice_PED
# 0  0.5789013093795381 (0.2699311478185185)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run052_vendor_dice_resized_wfluid.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus   0.537406296173186 (0.24951911422813655)
# 1  Spectralis  0.5478341814130545 (0.24388562786065027)
# 2      Topcon  0.6470754013053681 (0.21194682299030626)
#
#                                    dice_SRF  \
# 0  0.7090648215329438 (0.13724994578147987)
# 1  0.8281857187549273 (0.16730242048411714)
# 2   0.6778553801856629 (0.1597902940151348)
#
#                                    dice_PED
# 0  0.5773195446415159 (0.31504008600873656)
# 1   0.5733077208368251 (0.2859208597710128)
# 2  0.5830427888780833 (0.21731580329616546)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 053*
# - 7 patches
# - Train Folds: 2, 3, 0
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run053",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=25
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run053")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet",
    weights_name="Run053_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run053_class_dice_resized.csv")
class_df
# Out:
#                                    dice_IRF  \
# 0  0.6741698035695224 (0.39947442063404703)
#
#                                   dice_SRF  \
# 0  0.7978491944672292 (0.3699697980879971)
#
#                                  dice_PED
# 0  0.685923826769701 (0.4084861702835652)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run053_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus  0.7965374359773705 (0.33030084357434014)
# 1  Spectralis  0.7340927466902197 (0.34130348722348297)
# 2      Topcon   0.5334507698309607 (0.4333347561741554)
#
#                                    dice_SRF  \
# 0   0.8449363648542203 (0.3519843001036566)
# 1  0.7822739550349663 (0.38742245706884854)
# 2   0.7555319411563687 (0.3770521418526308)
#
#                                    dice_PED
# 0  0.8272291864210274 (0.33726224008307937)
# 1    0.6588235582244031 (0.380831936869194)
# 2   0.5529179243603721 (0.4349913640345017)

# %%
from pandas import read_csv

class_df = read_csv("results\\Run053_class_dice_resized_wfluid.csv")
class_df
# Out:
#                                    dice_IRF  \
# 0  0.6082089620097777 (0.22397740687280626)
#
#                                    dice_SRF  \
# 0  0.7315753427634676 (0.22913924603864025)
#
#                                    dice_PED
# 0  0.6576830147148995 (0.16172596252077348)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run053_vendor_dice_resized_wfluid.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus  0.6589197951275856 (0.23447775762453799)
# 1  Spectralis  0.6314199791301655 (0.19086285915441367)
# 2      Topcon  0.5461579932218389 (0.21097146808866069)
#
#                                   dice_SRF  \
# 0  0.5811551031382645 (0.3299019895855524)
# 1  0.9069786096205477 (0.1311632019336616)
# 2  0.6957720662825383 (0.1910310932532237)
#
#                                    dice_PED
# 0  0.5807247751027994 (0.19930050601869648)
# 1  0.6682644124936175 (0.16515776293353732)
# 2  0.6907844233544583 (0.12365242538269129)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 054*
# - 7 patches
# - Train Folds: 2, 3, 4
# - Validation Fold: 0
# - Test Fold: 0
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run054",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=25
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run054")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet",
    weights_name="Run054_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run054_class_dice_resized.csv")
class_df
# Out:
#                                    dice_IRF  \
# 0  0.7192326326405866 (0.37102379355200077)
#
#                                    dice_SRF  \
# 0  0.8358448066334684 (0.33694606786010034)
#
#                                    dice_PED
# 0  0.7615267296329024 (0.39038496984674614)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run054_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus  0.6770342022064142 (0.39109051460877053)
# 1  Spectralis  0.6805088178843868 (0.37411527757213925)
# 2      Topcon  0.7905106211037491 (0.33156280859586357)
#
#                                    dice_SRF  \
# 0  0.8421511012595146 (0.32652126758669664)
# 1   0.7986722426755087 (0.3537678250602938)
# 2   0.8457495910261059 (0.3409800524036123)
#
#                                    dice_PED
# 0   0.6990434149629436 (0.4251877344097513)
# 1  0.7318784987211836 (0.39986066460090686)
# 2   0.8538180147152161 (0.3163569023976843)

# %%
from pandas import read_csv

class_df = read_csv("results\\Run054_class_dice_resized_wfluid.csv")
class_df
# Out:
#                                   dice_IRF  \
# 0  0.6308643809298716 (0.2059733800899704)
#
#                                    dice_SRF  \
# 0  0.7635692088331423 (0.19714652593054266)
#
#                                    dice_PED
# 0  0.5883594970218837 (0.26262164382661507)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run054_vendor_dice_resized_wfluid.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus  0.6211356310427468 (0.19327094639530273)
# 1  Spectralis  0.6786608653592652 (0.23183656521276672)
# 2      Topcon  0.6065834825532836 (0.19703261465023272)
#
#                                    dice_SRF  \
# 0  0.7981235697990706 (0.13729811432310587)
# 1  0.8035217878910211 (0.21187085488876783)
# 2    0.56821055690179 (0.21707611741652663)
#
#                                    dice_PED
# 0   0.5851457834121634 (0.2944751486037069)
# 1  0.6662307959752825 (0.22876532775592093)
# 2  0.5271282546588631 (0.20177095011719973)

# %% [markdown]
# Compare Folds Results

# %%
from test_model import folds_results

folds_results(first_run_name="Run051", iteration=16, k=5, resized_images=True)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration16_vendors_results_resized.csv")
vendor_df
# Out:
#       vendors     dice_IRF     dice_SRF     dice_PED
# 0      Cirrus  0.62 (0.14)  0.81 (0.03)  0.68 (0.10)
# 1  Spectralis  0.65 (0.06)  0.80 (0.01)  0.74 (0.05)
# 2      Topcon  0.71 (0.10)  0.82 (0.04)  0.74 (0.11)

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration16_classes_results_resized.csv")
class_df
# Out:
#       dice_IRF     dice_SRF     dice_PED
# 0  0.65 (0.06)  0.81 (0.02)  0.71 (0.04)

# %% [markdown]
# ## Iteration 17 <a id="iteration17"></a>

# %% [markdown]
# *Run 055*
# - 7 patches
# - Train Folds: 3, 4, 0
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run055",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run055")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet",
    weights_name="Run055_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)
# Out:
# Testing Model:   0%|          | 0/1333 [00:00<?, ?img/s]

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run055_class_dice_resized.csv")
class_df
# Out:
#                                    dice_IRF  \
# 0  0.6584818918182496 (0.41061504033117957)
#
#                                   dice_SRF  \
# 0  0.8359515319528744 (0.3204567282843513)
#
#                                    dice_PED
# 0  0.7122802065150213 (0.40941029174795596)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run055_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                 dice_IRF  \
# 0      Cirrus    0.4970200543873943 (0.44336593809857)
# 1  Spectralis   0.7629993180231173 (0.310249612542463)
# 2      Topcon  0.8319836921208272 (0.3088469266362791)
#
#                                    dice_SRF  \
# 0    0.7825396720785648 (0.345020432389357)
# 1   0.8507548369923417 (0.3148583143136127)
# 2  0.9041586314727154 (0.26992265532573556)
#
#                                    dice_PED
# 0   0.6093926379078767 (0.4397568769121149)
# 1   0.8220744793512383 (0.3446617431805021)
# 2  0.7992187044250646 (0.35894504318432047)

# %%
from pandas import read_csv

class_df = read_csv("results\\Run055_class_dice_resized_wfluid.csv")
class_df
# Out:
#                                    dice_IRF  \
# 0  0.6130962391044662 (0.23131318869223272)
#
#                                   dice_SRF  \
# 0  0.784469401570642 (0.15033096933759865)
#
#                                    dice_PED
# 0  0.5533431561535288 (0.27439265832327586)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run055_vendor_dice_resized_wfluid.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus  0.6130514911410072 (0.23979108190627424)
# 1  Spectralis  0.6660460277682259 (0.15620219119335707)
# 2      Topcon  0.5639707439834565 (0.26391299319502626)
#
#                                    dice_SRF  \
# 0  0.7862286580105623 (0.12686070175097217)
# 1  0.8321918432126966 (0.13635485053643936)
# 2  0.7088552902384502 (0.23491449095102165)
#
#                                   dice_PED
# 0   0.546577257331634 (0.2846902540361151)
# 1  0.7424054986900753 (0.1997323521669877)
# 2  0.4527394463346429 (0.2294129441415207)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 056*
# - 7 patches
# - Train Folds: 2, 4, 0
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run056",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run056")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet",
    weights_name="Run056_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run056_class_dice_resized.csv")
class_df
# Out:
#                                    dice_IRF  \
# 0  0.5160954153134721 (0.44681692634107856)
#
#                                    dice_SRF  \
# 0  0.7804472836623809 (0.36463637742565447)
#
#                                    dice_PED
# 0  0.5116784574947958 (0.44905798211512205)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run056_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus  0.38983270923727104 (0.4275909480969204)
# 1  Spectralis  0.3964685969814962 (0.41598385134321936)
# 2      Topcon   0.7311670996496105 (0.4012199535851259)
#
#                                   dice_SRF  \
# 0  0.7256343997258228 (0.3826218836126869)
# 1  0.7356849667521156 (0.4113864638762073)
# 2  0.8703828566358425 (0.2941475967888341)
#
#                                    dice_PED
# 0  0.3201622976863291 (0.42608999922442203)
# 1  0.6171647583799703 (0.42626786917296755)
# 2   0.7005968140583718 (0.3873890551868864)

# %%
from pandas import read_csv

class_df = read_csv("results\\Run056_class_dice_resized_wfluid.csv")
class_df
# Out:
#                                    dice_IRF  \
# 0  0.5608648589034578 (0.21819990034906683)
#
#                                    dice_SRF  \
# 0  0.7213317607774546 (0.15568911052595538)
#
#                                    dice_PED
# 0  0.5945311435819001 (0.23478214614035037)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run056_vendor_dice_resized_wfluid.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus  0.5346412364847022 (0.21076973938867344)
# 1  Spectralis    0.5192330148290185 (0.239469592456664)
# 2      Topcon   0.645869000216848 (0.18873776019367755)
#
#                                    dice_SRF  \
# 0  0.6748889814299798 (0.14656892114453196)
# 1   0.8373802809044719 (0.1758205635309438)
# 2  0.7347400355828951 (0.09708075536120085)
#
#                                    dice_PED
# 0  0.5838759270711587 (0.25359765631349673)
# 1  0.5923764846550349 (0.26194822477329155)
# 2  0.6045520567605572 (0.20296499375530233)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 057*
# - 7 patches
# - Train Folds: 2, 3, 0
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run057",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run057")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet",
    weights_name="Run057_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)
# Out:
# Testing Model:   0%|          | 0/1476 [00:00<?, ?img/s]

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run057_class_dice_resized.csv")
class_df
# Out:
#                                  dice_IRF  \
# 0  0.5601645729821276 (0.431132422718421)
#
#                                   dice_SRF  \
# 0  0.6734586946141268 (0.4404047436731828)
#
#                                   dice_PED
# 0  0.6376959876785797 (0.4241742954031638)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run057_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus  0.6425449877162464 (0.41990427693777715)
# 1  Spectralis   0.6268540487757751 (0.3921837378922473)
# 2      Topcon  0.45736050628620434 (0.4324947226498611)
#
#                                    dice_SRF  \
# 0   0.7088343681767583 (0.4451961476839781)
# 1  0.8001522838461156 (0.36982872415083606)
# 2   0.5992831093491986 (0.4428125322734485)
#
#                                   dice_PED
# 0  0.747488913667621 (0.39950623216631426)
# 1  0.6350199168890106 (0.3828219010004488)
# 2  0.5287226083688438 (0.4324580396172989)

# %%
from pandas import read_csv

class_df = read_csv("results\\Run057_class_dice_resized_wfluid.csv")
class_df
# Out:
#                                   dice_IRF  \
# 0  0.6033959951729245 (0.2231916405205458)
#
#                                  dice_SRF  \
# 0  0.709263080679088 (0.2302504436818087)
#
#                                    dice_PED
# 0  0.6350118498991236 (0.14946670506615523)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run057_vendor_dice_resized_wfluid.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus   0.6911439606919885 (0.2050276345775076)
# 1  Spectralis  0.6185239691145813 (0.18901946726394564)
# 2      Topcon   0.506273181467206 (0.21568728100094578)
#
#                                   dice_SRF  \
# 0  0.6368822245036855 (0.2710277404697518)
# 1  0.8988499612104698 (0.1207438718924171)
# 2  0.6509050639967123 (0.2133160609192261)
#
#                                   dice_PED
# 0  0.6020967907312772 (0.1883778111016318)
# 1  0.6230111569166183 (0.1648954704655559)
# 2  0.6562897306173405 (0.1142650579967632)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 058*
# - 7 patches
# - Train Folds: 2, 3, 4
# - Validation Fold: 0
# - Test Fold: 0
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run058",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run058")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet",
    weights_name="Run058_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run058_class_dice_resized.csv")
class_df
# Out:
#                                   dice_IRF  \
# 0  0.7972702470660722 (0.3127447283593962)
#
#                                   dice_SRF  \
# 0  0.8690687069508034 (0.3017337083489827)
#
#                                   dice_PED
# 0  0.808159476196268 (0.35552366155928306)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run058_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus  0.7944704902009108 (0.31329610522996104)
# 1  Spectralis  0.8071941112377206 (0.28445487783282847)
# 2      Topcon  0.7960212190810125 (0.32522140609409816)
#
#                                    dice_SRF  \
# 0   0.8780959847383201 (0.2870182908333658)
# 1  0.9020584718305238 (0.22813254117339174)
# 2   0.8419984917563852 (0.3456835217546726)
#
#                                    dice_PED
# 0   0.7703296402585693 (0.3826539412044888)
# 1  0.8621158075319337 (0.29555882981788884)
# 2   0.8296278235065984 (0.3418196579067994)

# %%
from pandas import read_csv

class_df = read_csv("results\\Run058_class_dice_resized_wfluid.csv")
class_df
# Out:
#                                    dice_IRF  \
# 0  0.6266663880324213 (0.21201250088236076)
#
#                                   dice_SRF  \
# 0  0.7610640325225316 (0.2141554249647409)
#
#                                    dice_PED
# 0  0.5847406281618069 (0.27028658088737045)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run058_vendor_dice_resized_wfluid.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF  \
# 0      Cirrus  0.6265779987257412 (0.19491466430040733)
# 1  Spectralis  0.7048496314934616 (0.22352162046586244)
# 2      Topcon   0.563376672513835 (0.20708217270921697)
#
#                                     dice_SRF  \
# 0   0.8149700019539905 (0.13267716118982636)
# 1   0.8077477640830554 (0.20277517570955456)
# 2  0.48927642646673564 (0.24685812737258284)
#
#                                    dice_PED
# 0  0.5902538505367568 (0.28518765084685915)
# 1  0.6456296763268633 (0.28812812408114685)
# 2  0.5208105841865305 (0.20657016013722274)

# %% [markdown]
# Compare Folds Results

# %%
from test_model import folds_results

folds_results(first_run_name="Run055", iteration=17, k=5, resized_images=True)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration17_vendors_results_resized.csv")
vendor_df
# Out:
#       vendors     dice_IRF     dice_SRF     dice_PED
# 0      Cirrus  0.58 (0.15)  0.77 (0.07)  0.61 (0.18)
# 1  Spectralis  0.65 (0.16)  0.82 (0.06)  0.73 (0.11)
# 2      Topcon  0.70 (0.15)  0.80 (0.12)  0.71 (0.12)

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration17_classes_results_resized.csv")
class_df
# Out:
#       dice_IRF     dice_SRF     dice_PED
# 0  0.63 (0.11)  0.79 (0.07)  0.67 (0.11)

# %% [markdown]
# ## Iteration 18 <a id="iteration18"></a>

# %% [markdown]
# *Run 059*
# - 4 patches
# - Train Folds: 3, 4, 0
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run059",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=4,
    patience_after_n=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run059")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet",
    weights_name="Run059_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run059_class_dice_resized.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run059_vendor_dice_resized.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Run059_class_dice_resized_wfluid.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run059_vendor_dice_resized_wfluid.csv")
vendor_df

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 060*
# - 4 patches
# - Train Folds: 2, 4, 0
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run060",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=4,
    patience_after_n=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run060")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet",
    weights_name="Run060_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run060_class_dice_resized.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run060_vendor_dice_resized.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Run060_class_dice_resized_wfluid.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run060_vendor_dice_resized_wfluid.csv")
vendor_df

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 061*
# - 4 patches
# - Train Folds: 2, 3, 0
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run061",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=4,
    patience_after_n=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run061")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet",
    weights_name="Run061_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run061_class_dice_resized.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run061_vendor_dice_resized.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Run061_class_dice_resized_wfluid.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run061_vendor_dice_resized_wfluid.csv")
vendor_df

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 062*
# - 4 patches
# - Train Folds: 2, 3, 4
# - Validation Fold: 0
# - Test Fold: 0
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run062",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=4,
    patience_after_n=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run062")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet",
    weights_name="Run062_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run062_class_dice_resized.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run062_vendor_dice_resized.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Run062_class_dice_resized_wfluid.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run062_vendor_dice_resized_wfluid.csv")
vendor_df

# %% [markdown]
# Compare Folds Results

# %%
from test_model import folds_results

folds_results(first_run_name="Run059", iteration=18, k=5, resized_images=True)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration18_vendors_results_resized.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration18_classes_results_resized.csv")
class_df
