# %% [markdown]
# # U-Net Runs

# %% [markdown]
# ## Table of Contents
# * [Iteration 9](#iteration9)
# * [Iteration 10](#iteration10)

# %% [markdown]
# ## Iteration 9 <a id="iteration9"></a>

# %% [markdown]
# *Run 023*
# - Train Folds: 3, 4, 5
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run023",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=100,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Training

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run023")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet",
    weights_name="Run023_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True
)

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet",
    weights_name="Run023_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run023_class_dice.csv")
class_df
# Out:
#    Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0         0.984557  0.283569  0.315086  0.247646

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run023_vendor_dice.csv")
vendor_df
# Out:
#        vendor  Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0      Cirrus         0.979458  0.239371  0.235004  0.254394
# 1  Spectralis         0.996854  0.736650  0.880882  0.773210
# 2      Topcon         0.989399  0.264580  0.403193  0.100475

# %%
from pandas import read_csv

class_df = read_csv("results\\Run023_class_dice_resized.csv")
class_df
# Out:
#    Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0         0.996786  0.683793  0.816967   0.70959

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run023_vendor_dice_resized.csv")
vendor_df
# Out:
#        vendor  Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0      Cirrus         0.995365  0.654876  0.789735  0.706407
# 1  Spectralis         0.996854  0.736650  0.880882  0.773210
# 2      Topcon         0.998752  0.679585  0.808679  0.599696

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 024*
# - Train Folds: 2, 4, 5
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run024",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=100,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128),
    n_pos=12, 
    n_neg=0, 
    pos=1,
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run024")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet",
    weights_name="Run024_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True
)

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet",
    weights_name="Run024_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run024_class_dice.csv")
class_df
# Out:
#    Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0         0.991121  0.232451   0.26582  0.271453

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run024_vendor_dice.csv")
vendor_df
# Out:
#        vendor  Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0      Cirrus         0.986641  0.161886  0.095140  0.141635
# 1  Spectralis         0.996316  0.561163  0.792954  0.631109
# 2      Topcon         0.997338  0.505401  0.560405  0.466219

# %%
from pandas import read_csv

class_df = read_csv("results\\Run024_class_dice_resized.csv")
class_df
# Out:
#    Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0         0.995874   0.47387  0.586148  0.545876

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run024_vendor_dice_resized.csv")
vendor_df
# Out:
#        vendor  Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0      Cirrus         0.994316  0.388837  0.489203  0.527896
# 1  Spectralis         0.996316  0.561163  0.792954  0.631109
# 2      Topcon         0.997600  0.569798  0.661961  0.526153

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 025*
# - Train Folds: 2, 3, 5
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run025",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=100,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run025")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet",
    weights_name="Run025_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True
)

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet",
    weights_name="Run025_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run025_class_dice.csv")
class_df
# Out:
#    Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0         0.988193  0.268369  0.569981  0.311141

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run025_vendor_dice.csv")
vendor_df
# Out:
#        vendor  Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0      Cirrus         0.987637  0.275396  0.048136  0.037842
# 1  Spectralis         0.996782  0.761139  0.939551  0.706134
# 2      Topcon         0.987215  0.152179  0.663006  0.400503

# %%
from pandas import read_csv

class_df = read_csv("results\\Run025_class_dice_resized.csv")
class_df
# Out:
#    Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0         0.996726  0.709103  0.817086  0.614097

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run025_vendor_dice_resized.csv")
vendor_df
# Out:
#        vendor  Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0      Cirrus         0.998649  0.802926  0.598867  0.662344
# 1  Spectralis         0.996782  0.761139  0.939551  0.706134
# 2      Topcon         0.994771  0.499052  0.702893  0.596060

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 026*
# - Train Folds: 2, 3, 4
# - Validation Fold: 5
# - Test Fold: 5
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run026",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=100,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run026")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet",
    weights_name="Run026_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True
)

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet",
    weights_name="Run026_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run026_class_dice.csv")
class_df
# Out:
#    Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0         0.988815  0.352673  0.268878  0.246376

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run026_vendor_dice.csv")
vendor_df
# Out:
#        vendor  Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0      Cirrus         0.982740  0.313966  0.158195  0.189878
# 1  Spectralis         0.997053  0.748465  0.873667  0.714993
# 2      Topcon         0.995639  0.350274  0.410272  0.356127

# %%
from pandas import read_csv

class_df = read_csv("results\\Run026_class_dice_resized.csv")
class_df
# Out:
#    Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0         0.997798  0.717036  0.868625  0.672661

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run026_vendor_dice_resized.csv")
vendor_df
# Out:
#        vendor  Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0      Cirrus         0.997186  0.716342  0.874843  0.660029
# 1  Spectralis         0.997053  0.748465  0.873667  0.714993
# 2      Topcon         0.998909  0.686197  0.615298  0.612739

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# Compare Folds Results

# %%
from test_model import folds_results

folds_results(first_run_name="Run023", iteration=9, k=5)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration9_vendors_results.csv")
vendor_df
# Out:
#    Unnamed: 0 Dice_Background     Dice_IRF     Dice_SRF     Dice_PED
# 0      Cirrus     0.98 (0.00)  0.25 (0.06)  0.13 (0.07)  0.16 (0.08)
# 1  Spectralis     1.00 (0.00)  0.70 (0.08)  0.87 (0.05)  0.71 (0.05)
# 2      Topcon     0.99 (0.00)  0.32 (0.13)  0.51 (0.11)  0.33 (0.14)

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration9_classes_results.csv")
class_df
# Out:
#   Dice_Background     Dice_IRF     Dice_SRF     Dice_PED
# 0     0.99 (0.00)  0.28 (0.04)  0.35 (0.13)  0.27 (0.03)

# %%
from test_model import folds_results

folds_results(first_run_name="Run023", iteration=9, k=5, resized_images=True)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration9_vendors_results_resized.csv")
vendor_df
# Out:
#    Unnamed: 0 Dice_Background     Dice_IRF     Dice_SRF     Dice_PED
# 0      Cirrus     1.00 (0.00)  0.64 (0.15)  0.69 (0.15)  0.64 (0.07)
# 1  Spectralis     1.00 (0.00)  0.70 (0.08)  0.87 (0.05)  0.71 (0.05)
# 2      Topcon     1.00 (0.00)  0.61 (0.08)  0.70 (0.07)  0.58 (0.03)

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration9_classes_results_resized.csv")
class_df
# Out:
#   Dice_Background     Dice_IRF     Dice_SRF     Dice_PED
# 0     1.00 (0.00)  0.65 (0.10)  0.77 (0.11)  0.64 (0.06)

# %% [markdown]
# ## Iteration 10 <a id="iteration10"></a>
# - U-Net
# - 200 Epochs

# %% [markdown]
# *Run 027*
# - Train Folds: 3, 4, 5
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run027",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run027")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet",
    weights_name="Run027_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True
)

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet",
    weights_name="Run027_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run027_class_dice.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run027_vendor_dice.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Run027_class_dice_resized.csv")
class_df
# Out:
#    Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0         0.996861  0.691094  0.803486  0.685406

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run027_vendor_dice_resized.csv")
vendor_df
# Out:
#        vendor  Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0      Cirrus         0.995493  0.667499  0.780967  0.672351
# 1  Spectralis         0.996691  0.722135  0.860957  0.801100
# 2      Topcon         0.998883  0.711321  0.772901  0.588400

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 028*
# - Train Folds: 2, 4, 5
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run028",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run028")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet",
    weights_name="Run028_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True
)

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet",
    weights_name="Run028_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run028_class_dice.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run028_vendor_dice.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Run028_class_dice_resized.csv")
class_df
# Out:
#    Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0         0.997117  0.626025  0.745218  0.610816

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run028_vendor_dice_resized.csv")
vendor_df
# Out:
#        vendor  Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0      Cirrus         0.996293  0.600895  0.741721  0.629225
# 1  Spectralis         0.997169  0.634032  0.835112  0.607300
# 2      Topcon         0.998115  0.701995  0.477734  0.586243

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 029*
# - Train Folds: 2, 3, 5
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run029",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run029")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet",
    weights_name="Run029_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True
)

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet",
    weights_name="Run029_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run029_class_dice.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run029_vendor_dice.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Run029_class_dice_resized.csv")
class_df
# Out:
#    Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0         0.996255  0.664516  0.712848  0.531554

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run029_vendor_dice_resized.csv")
vendor_df
# Out:
#        vendor  Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0      Cirrus         0.998025  0.757261  0.319564  0.498606
# 1  Spectralis         0.995885  0.728923  0.872010  0.592953
# 2      Topcon         0.994586  0.403708  0.670881  0.528227

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 030*
# - Train Folds: 2, 3, 4
# - Validation Fold: 5
# - Test Fold: 5
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run030",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run030")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet",
    weights_name="Run030_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True
)

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet",
    weights_name="Run030_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run030_class_dice.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run030_vendor_dice.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Run030_class_dice_resized.csv")
class_df
# Out:
#    Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0         0.997532  0.693958  0.812591  0.629679

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run030_vendor_dice_resized.csv")
vendor_df
# Out:
#        vendor  Dice_Background  Dice_IRF  Dice_SRF  Dice_PED
# 0      Cirrus         0.996914  0.682789  0.849306  0.643275
# 1  Spectralis         0.997197  0.732878  0.862289  0.692745
# 2      Topcon         0.998456  0.680656  0.214409  0.434236

# %% [markdown]
# Compare Folds Results

# %%
from test_model import folds_results

folds_results(first_run_name="Run027", iteration=10, k=5)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration10_vendors_results.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration10_classes_results.csv")
class_df

# %%
from test_model import folds_results

folds_results(first_run_name="Run027", iteration=10, k=5, resized_images=True)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration10_vendors_results_resized.csv")
vendor_df
# Out:
#    Unnamed: 0 Dice_Background     Dice_IRF     Dice_SRF     Dice_PED
# 0      Cirrus     1.00 (0.00)  0.68 (0.06)  0.67 (0.21)  0.61 (0.07)
# 1  Spectralis     1.00 (0.00)  0.70 (0.04)  0.86 (0.01)  0.67 (0.08)
# 2      Topcon     1.00 (0.00)  0.62 (0.13)  0.53 (0.21)  0.53 (0.06)

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration10_classes_results_resized.csv")
class_df
# Out:
#   Dice_Background     Dice_IRF     Dice_SRF     Dice_PED
# 0     1.00 (0.00)  0.67 (0.03)  0.77 (0.04)  0.61 (0.06)

# %% [markdown]
# ## Iteration 11 <a id="iteration11"></a>

# %% [markdown]
# *Run 031*
# - Train Folds: 3, 4, 5
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run031",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=100,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100,
    num_patches=7
)

# %% [markdown]
# Training

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run031")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet",
    weights_name="Run031_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run031_class_dice_resized.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run031_vendor_dice_resized.csv")
vendor_df

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 032*
# - Train Folds: 2, 4, 5
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run032",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=100,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128),
    n_pos=12, 
    n_neg=0, 
    pos=1,
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100,
    num_patches=7
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run032")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet",
    weights_name="Run032_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run032_class_dice_resized.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run032_vendor_dice_resized.csv")
vendor_df

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 033*
# - Train Folds: 2, 3, 5
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run033",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=100,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100,
    num_patches=7
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run033")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet",
    weights_name="Run033_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run033_class_dice_resized.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run033_vendor_dice_resized.csv")
vendor_df

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 026*
# - Train Folds: 2, 3, 4
# - Validation Fold: 5
# - Test Fold: 5
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run034",
    model_name="UNet",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=100,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=4,
    number_of_channels=1,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=100,
    num_patches=7
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_vertical_imgs", run_name="Run034")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet",
    weights_name="Run034_UNet_best_model.pth",
    number_of_channels=1,
    number_of_classes=4,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run034_class_dice_resized.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run034_vendor_dice_resized.csv")
vendor_df

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# Compare Folds Results

# %%
from test_model import folds_results

folds_results(first_run_name="Run031", iteration=11, k=5, resized_images=True)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration11_vendors_results_resized.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration11_classes_results_resized.csv")
class_df
