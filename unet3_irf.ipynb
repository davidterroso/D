# %% [markdown]
# # IRF U-Net Runs

# %% [markdown]
# ## Results & Logs
#
# To see logs and results of this run please check the folders in [this commit](https://github.com/davidterroso/D/commit/d131a81f6bf609ba79b8429852bdf67713d3f14a) and in [this commit](https://github.com/davidterroso/D/commit/40c8b3545772b739a4cb3a4c3e5b51c13bc12ea9).

# %% [markdown]
# ## Table of Contents
# * [Iteration 19](#iteration19)
# * [Iteration 22](#iteration22)
# * [Final Testing](#finaltesting)
# * [Iteration 26](#iteration26)
# * [Final Testing - Relative Distance Maps](#finaltestingrdm)

# %% [markdown]
# ## Iteration 19 <a id="iteration19"></a>

# %% [markdown]
# *Run 063*
# - Train Folds: 3, 4, 5
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run063",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="IRF"
)

# %% [markdown]
# Training

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_irf_imgs", run_name="Run063")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet3",
    weights_name="Run063_IRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="IRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run063_class_dice_resized.csv")
class_df
# Out:
#                                   AllSlices  \
# 0  0.6044116486590537 (0.42709378090189665)
#
#                             SlicesWithFluid  \
# 0  0.6251362534535908 (0.22193689951032872)
#
#                          SlicesWithoutFluid
# 0  0.5952380952380952 (0.49111173285565135)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run063_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF
# 0      Cirrus  0.47826417882461103 (0.4423749843630222)
# 1  Spectralis  0.6948805714140133 (0.35692474878714975)
# 2      Topcon   0.7351471277194962 (0.3871197579429302)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 064*
# - Train Folds: 2, 4, 5
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run064",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128),
    n_pos=12, 
    n_neg=0, 
    pos=1,
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="IRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_irf_imgs", run_name="Run064")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet3",
    weights_name="Run064_IRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="IRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run064_class_dice_resized.csv")
class_df
# Out:
#                                   AllSlices  \
# 0  0.6365028587073279 (0.43342798004114397)
#
#                            SlicesWithFluid  \
# 0  0.5529589054224849 (0.2733036719458524)
#
#                          SlicesWithoutFluid
# 0  0.6647509578544061 (0.47230370655576137)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run064_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF
# 0      Cirrus    0.5362467861588811 (0.450871710533256)
# 1  Spectralis  0.5140373900760802 (0.42964148359065396)
# 2      Topcon   0.8204245896558859 (0.3423351019786067)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 065*
# - Train Folds: 2, 3, 5
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run065",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="IRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_irf_imgs", run_name="Run065")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet3",
    weights_name="Run065_IRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="IRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run065_class_dice_resized.csv")
class_df
# Out:
#                                   AllSlices  \
# 0  0.5521647717876594 (0.43548658836924775)
#
#                             SlicesWithFluid  \
# 0  0.5995661083868333 (0.24411957351762828)
#
#                         SlicesWithoutFluid
# 0  0.5298804780876494 (0.4993551032081982)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run065_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                 dice_IRF
# 0      Cirrus  0.5447661209851503 (0.4397034986126694)
# 1  Spectralis  0.6171735950878688 (0.3989174676665051)
# 2      Topcon  0.5396544704544795 (0.4408574559213057)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 066*
# - Train Folds: 2, 3, 4
# - Validation Fold: 5
# - Test Fold: 5
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run066",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="IRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_irf_imgs", run_name="Run066")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet3",
    weights_name="Run066_IRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="IRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run066_class_dice_resized.csv")
class_df
# Out:
#                                  AllSlices  \
# 0  0.6282377545385166 (0.4061972929680455)
#
#                            SlicesWithFluid  \
# 0  0.6284918285811604 (0.1740336800935855)
#
#                         SlicesWithoutFluid
# 0  0.6281081081081081 (0.4835712086560922)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run066_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF
# 0      Cirrus   0.576259740954265 (0.41793778736046533)
# 1  Spectralis   0.6945711315286403 (0.3525573029349306)
# 2      Topcon  0.6614687141700415 (0.40789287055909235)

# %% [markdown]
# Compare Folds Results

# %%
from test_model import folds_results

folds_results(first_run_name="Run063", iteration=19, k=5, resized_images=True, binary_segmentation=True)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration19_vendors_results_resized.csv")
vendor_df
# Out:
#       vendors     dice_IRF
# 0      Cirrus  0.53 (0.04)
# 1  Spectralis  0.63 (0.07)
# 2      Topcon  0.69 (0.10)

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration19_classes_results_resized.csv")
class_df
# Out:
#      AllSlices SlicesWithFluid SlicesWithoutFluid
# 0  0.61 (0.03)     0.60 (0.03)        0.60 (0.05)

# %% [markdown]
# ## Iteration 22 <a id="iteration22"></a>

# %% [markdown]
# *Run 075*
# - Train Folds: 3, 4, 5
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run075",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_IRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="IRF"
)

# %% [markdown]
# Training

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_irf_imgs", run_name="Run075")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet3",
    weights_name="Run075_IRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="IRF",
    split="competitive_fold_selection_IRF.csv"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run075_class_dice_resized.csv")
class_df
# Out:
#                                  AllSlices  \
# 0  0.632022541377336 (0.40816588535306847)
#
#                             SlicesWithFluid  \
# 0  0.6351676280473304 (0.22537697662239553)
#
#                          SlicesWithoutFluid
# 0  0.6302142051860203 (0.48301893379811284)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run075_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                 dice_IRF
# 0      Cirrus  0.6540708523869398 (0.4116119622029409)
# 1  Spectralis  0.5409261431012835 (0.3855877050120481)
# 2      Topcon  0.6480532025716457 (0.4091834915581545)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 076*
# - Train Folds: 2, 4, 5
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run076",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_IRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128),
    n_pos=12, 
    n_neg=0, 
    pos=1,
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="IRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_irf_imgs", run_name="Run076")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet3",
    weights_name="Run076_IRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="IRF",
    split="competitive_fold_selection_IRF.csv"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run076_class_dice_resized.csv")
class_df
# Out:
#                                  AllSlices  \
# 0  0.6487506001863876 (0.4175370974669858)
#
#                            SlicesWithFluid  \
# 0  0.6557036925081107 (0.1804319902651347)
#
#                         SlicesWithoutFluid
# 0  0.6460784313725491 (0.4784197836904206)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run076_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF
# 0      Cirrus    0.50662292538982 (0.42821328027047756)
# 1  Spectralis  0.7413595765829086 (0.33774905526665366)
# 2      Topcon   0.7751574621587578 (0.3793843206171863)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 077*
# - Train Folds: 2, 3, 5
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run077",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_IRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="IRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_irf_imgs", run_name="Run077")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet3",
    weights_name="Run077_IRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="IRF",
    split="competitive_fold_selection_IRF.csv"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run077_class_dice_resized.csv")
class_df
# Out:
#                                  AllSlices  \
# 0  0.5015875415459179 (0.4498231371741407)
#
#                           SlicesWithFluid  \
# 0  0.545677036993572 (0.2561984178105811)
#
#                         SlicesWithoutFluid
# 0  0.4859359844810863 (0.5000447278780342)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run077_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF
# 0      Cirrus  0.5830066437483765 (0.45528166882189897)
# 1  Spectralis   0.6892996724162783 (0.3437252930391444)
# 2      Topcon  0.3099904761693324 (0.41854401303316296)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 078*
# - Train Folds: 2, 3, 4
# - Validation Fold: 5
# - Test Fold: 5
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run078",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_IRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="IRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_irf_imgs", run_name="Run078")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet3",
    weights_name="Run078_IRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="IRF",
    split="competitive_fold_selection_IRF.csv"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run078_class_dice_resized.csv")
class_df
# Out:
#                                   AllSlices  \
# 0  0.6113131998517499 (0.42102210516966115)
#
#                             SlicesWithFluid  \
# 0  0.5936176716732754 (0.22012778785772738)
#
#                         SlicesWithoutFluid
# 0  0.6193952033368092 (0.4857889105073906)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run078_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF
# 0      Cirrus  0.6177474934243946 (0.41899200400359027)
# 1  Spectralis   0.6435003249620904 (0.4333288439684054)
# 2      Topcon    0.5878682905968162 (0.417092366145082)

# %% [markdown]
# Compare Folds Results

# %%
from test_model import folds_results

folds_results(first_run_name="Run075", iteration=22, k=5, resized_images=True, binary_segmentation=True)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration22_vendors_results_resized.csv")
vendor_df
# Out:
#       vendors     dice_IRF
# 0      Cirrus  0.59 (0.05)
# 1  Spectralis  0.65 (0.07)
# 2      Topcon  0.58 (0.17)

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration22_classes_results_resized.csv")
class_df
# Out:
#      AllSlices SlicesWithFluid SlicesWithoutFluid
# 0  0.60 (0.06)     0.61 (0.04)        0.60 (0.06)

# %% [markdown]
# ## Final Testing <a id="finaltesting"></a>

# %%
from test_model import test_model

test_model(
    fold_test=1,
    model_name="UNet3",
    weights_name="Run0XX_IRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False,
    resize_images=True,
    final_test=True
)

# %%
from pandas import read_csv

class_df = read_csv("results\\Run0XX_class_dice_resized_final.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run0XX_vendor_dice_resized_final.csv")
vendor_df

# %% [markdown]
# ## Iteration 26 <a id="iteration26"></a>

# %% [markdown]
# *Run 091*
# - With relative distance maps
# - Train Folds: 3, 4, 5
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run091",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_IRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=2,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="IRF"
)

# %% [markdown]
# Training

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_irf_imgs", run_name="Run091")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet3",
    weights_name="Run091_IRF_UNet3_best_model.pth",
    number_of_channels=2,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="IRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run091_class_dice_resized.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run091_vendor_dice_resized.csv")
vendor_df

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 092*
# - With relative distance maps
# - Train Folds: 2, 4, 5
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run092",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_IRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=2,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128),
    n_pos=12, 
    n_neg=0, 
    pos=1,
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="IRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_irf_imgs", run_name="Run092")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet3",
    weights_name="Run092_IRF_UNet3_best_model.pth",
    number_of_channels=2,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="IRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run092_class_dice_resized.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run092_vendor_dice_resized.csv")
vendor_df

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 093*
# - With relative distance maps
# - Train Folds: 2, 3, 5
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run093",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_IRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=2,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="IRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_irf_imgs", run_name="Run093")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet3",
    weights_name="Run093_IRF_UNet3_best_model.pth",
    number_of_channels=2,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="IRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run093_class_dice_resized.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run093_vendor_dice_resized.csv")
vendor_df

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 094*
# - With relative distance maps
# - Train Folds: 2, 3, 4
# - Validation Fold: 5
# - Test Fold: 5
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run094",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_IRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=2,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="IRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_irf_imgs", run_name="Run094")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet3",
    weights_name="Run094_IRF_UNet3_best_model.pth",
    number_of_channels=2,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="IRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run094_class_dice_resized.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run094_vendor_dice_resized.csv")
vendor_df

# %% [markdown]
# Compare Folds Results

# %%
from test_model import folds_results

folds_results(first_run_name="Run091", iteration=26, k=5, resized_images=True, binary_segmentation=True)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration26_vendors_results_resized.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration26_classes_results_resized.csv")
class_df

# %% [markdown]
# ## Final Testing - Relative Distance Maps <a id="finaltestingrdm"></a>

# %%
from test_model import test_model

test_model(
    fold_test=1,
    model_name="UNet3",
    weights_name="Run0XX_IRF_UNet3_best_model.pth",
    number_of_channels=2,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False,
    resize_images=True,
    final_test=True
)

# %%
from pandas import read_csv

class_df = read_csv("results\\Run0XX_class_dice_resized_final.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run0XX_vendor_dice_resized_final.csv")
vendor_df
