# %% [markdown]
# # U-Net Runs

# %% [markdown]
# ## Table of Contents
# * [Iteration 19](#iteration19)

# %% [markdown]
# ## Iteration 19 <a id="iteration19"></a>

# %% [markdown]
# *Run 063*
# - Train Folds: 3, 4, 5
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run063",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="IRF"
)

# %% [markdown]
# Training

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_irf_imgs", run_name="Run063")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet3",
    weights_name="Run063_IRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False,
    resize_images=True,
    fluid="IRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run063_class_dice_resized.csv")
class_df
# Out:
#                                   AllSlices  \
# 0  0.6044116486590537 (0.42709378090189665)
#
#                             SlicesWithFluid  \
# 0  0.6251362534535908 (0.22193689951032872)
#
#                          SlicesWithoutFluid
# 0  0.5952380952380952 (0.49111173285565135)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run063_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_IRF
# 0      Cirrus  0.47826417882461103 (0.4423749843630222)
# 1  Spectralis  0.6948805714140133 (0.35692474878714975)
# 2      Topcon   0.7351471277194962 (0.3871197579429302)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 064*
# - Train Folds: 2, 4, 5
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run064",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128),
    n_pos=12, 
    n_neg=0, 
    pos=1,
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="IRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_irf_imgs", run_name="Run064")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet3",
    weights_name="Run064_IRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run064_class_dice_resized.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run064_vendor_dice_resized.csv")
vendor_df

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 065*
# - Train Folds: 2, 3, 5
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run065",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="IRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_irf_imgs", run_name="Run065")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet3",
    weights_name="Run065_IRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run025_class_dice_resized.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run025_vendor_dice_resized.csv")
vendor_df

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 066*
# - Train Folds: 2, 3, 4
# - Validation Fold: 5
# - Test Fold: 5
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run066",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="IRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet_irf_imgs", run_name="Run066")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet3",
    weights_name="Run066_IRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run066_class_dice_resized.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run066_vendor_dice_resized.csv")
vendor_df

# %% [markdown]
# Compare Folds Results

# %%
from test_model import folds_results

folds_results(first_run_name="Run063", iteration=19, k=5, resized_images=True)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration19_vendors_results_resized.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration19_classes_results_resized.csv")
class_df
