# %% [markdown]
# # SRF U-Net Runs

# %% [markdown]
# ## Results & Logs
#
# To see logs and results of this run please check the folders in [this commit](https://github.com/davidterroso/D/commit/d131a81f6bf609ba79b8429852bdf67713d3f14a) and in [this commit](https://github.com/davidterroso/D/commit/19a52b716406aeae2b3f7ed1bc14da88e4ad2606).

# %% [markdown]
# ## Table of Contents
# * [Iteration 20](#iteration20)
# * [Iteration 23](#iteration23)

# %% [markdown]
# ## Iteration 20 <a id="iteration20"></a>

# %% [markdown]
# *Run 067*
# - Train Folds: 3, 4, 5
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run067",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Training

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run067")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet3",
    weights_name="Run067_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run067_class_dice_resized.csv")
class_df
# Out:
#                                  AllSlices  \
# 0  0.899402646606387 (0.24408986437660005)
#
#                            SlicesWithFluid  \
# 0  0.7735787513576875 (0.2096124479051313)
#
#                          SlicesWithoutFluid
# 0  0.9381746810598626 (0.24095627452828336)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run067_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_SRF
# 0      Cirrus  0.8662717961007729 (0.26318210091635197)
# 1  Spectralis   0.8818559201700347 (0.2800857328211226)
# 2      Topcon    0.9563282990628588 (0.175254068748992)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 068*
# - Train Folds: 2, 4, 5
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run068",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128),
    n_pos=12, 
    n_neg=0, 
    pos=1,
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run068")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet3",
    weights_name="Run068_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run068_class_dice_resized.csv")
class_df
# Out:
#                                  AllSlices  \
# 0  0.7047684122898277 (0.4122374996022832)
#
#                             SlicesWithFluid  \
# 0  0.6663206314766094 (0.21612272649852227)
#
#                         SlicesWithoutFluid
# 0  0.7154620311070449 (0.4514006404107886)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run068_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_SRF
# 0      Cirrus  0.5987811713013798 (0.43323402737729366)
# 1  Spectralis   0.7411239905016763 (0.4073732835515621)
# 2      Topcon   0.8198557512951083 (0.3497657517828466)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 069*
# - Train Folds: 2, 3, 5
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run069",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run069")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet3",
    weights_name="Run069_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run069_class_dice_resized.csv")
class_df
# Out:
#                                  AllSlices  \
# 0  0.8155054538094295 (0.3541680174421931)
#
#                             SlicesWithFluid  \
# 0  0.7278328678195932 (0.22507091331916065)
#
#                         SlicesWithoutFluid
# 0  0.833469387755102 (0.37270841770189517)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run069_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_SRF
# 0      Cirrus   0.7686545695585665 (0.4104089264879691)
# 1  Spectralis   0.8738106525674159 (0.2861670161341126)
# 2      Topcon  0.8445003709406592 (0.30336742226108016)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 070*
# - Train Folds: 2, 3, 4
# - Validation Fold: 5
# - Test Fold: 5
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run070",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run070")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet3",
    weights_name="Run070_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run070_class_dice_resized.csv")
class_df
# Out:
#                                   AllSlices  \
# 0  0.7229430738439198 (0.41973057868117647)
#
#                             SlicesWithFluid  \
# 0  0.7647498895724615 (0.18785975703595237)
#
#                          SlicesWithoutFluid
# 0  0.7145313843508169 (0.45183163246969926)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run070_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_SRF
# 0      Cirrus   0.6665748225990683 (0.4399989741800542)
# 1  Spectralis    0.7654751649316476 (0.379570574495685)
# 2      Topcon  0.7730511177505832 (0.40377977121935976)

# %% [markdown]
# Compare Folds Results

# %%
from test_model import folds_results

folds_results(first_run_name="Run067", iteration=20, k=5, resized_images=True, binary_segmentation=True)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration20_vendors_results_resized.csv")
vendor_df
# Out:
#       vendors     dice_SRF
# 0      Cirrus  0.73 (0.10)
# 1  Spectralis  0.82 (0.06)
# 2      Topcon  0.85 (0.07)

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration20_classes_results_resized.csv")
class_df
# Out:
#      AllSlices SlicesWithFluid SlicesWithoutFluid
# 0  0.79 (0.08)     0.73 (0.04)        0.80 (0.09)

# %% [markdown]
# ## Iteration 23 <a id="iteration23"></a>

# %% [markdown]
# *Run 079*
# - Train Folds: 3, 4, 5
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run079",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_SRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Training

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run079")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet3",
    weights_name="Run079_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run079_class_dice_resized.csv")
class_df
# Out:
#                                  AllSlices  \
# 0  0.7818183559429708 (0.3719581910171177)
#
#                            SlicesWithFluid  \
# 0  0.7903307913120385 (0.1689788256318347)
#
#                          SlicesWithoutFluid
# 0  0.7791952894995093 (0.41499276881690816)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run079_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                 dice_SRF
# 0      Cirrus  0.6613833367824554 (0.4214100239767303)
# 1  Spectralis  0.8562526834254363 (0.3134351522168557)
# 2      Topcon  0.9131621104731623 (0.2523646948693363)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 080*
# - Train Folds: 2, 4, 5
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run080",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_SRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128),
    n_pos=12, 
    n_neg=0, 
    pos=1,
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run080")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet3",
    weights_name="Run080_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run080_class_dice_resized.csv")
class_df
# Out:
#                                   AllSlices  \
# 0  0.7710255361158793 (0.37349867180978813)
#
#                             SlicesWithFluid  \
# 0  0.7010614274798794 (0.19751556789706762)
#
#                         SlicesWithoutFluid
# 0  0.7904849039341263 (0.4071488498059079)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run080_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_SRF
# 0      Cirrus  0.6751248135813512 (0.40795054809535986)
# 1  Spectralis   0.7613075857259789 (0.4053587074091797)
# 2      Topcon  0.8955516303885815 (0.25967531237007985)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 081*
# - Train Folds: 2, 3, 5
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run081",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_SRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run081")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet3",
    weights_name="Run081_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run081_class_dice_resized.csv")
class_df
# Out:
#                                  AllSlices  \
# 0  0.8909291308597999 (0.2796986473506787)
#
#                            SlicesWithFluid  \
# 0  0.8287306659325282 (0.1742154311569592)
#
#                         SlicesWithoutFluid
# 0  0.9036734693877551 (0.2951590207651049)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run081_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_SRF
# 0      Cirrus  0.8974998963001781 (0.29144879297082404)
# 1  Spectralis  0.9226780003126787 (0.20523297865845816)
# 2      Topcon   0.8746352741494775 (0.2866470129667431)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 082*
# - Train Folds: 2, 3, 4
# - Validation Fold: 5
# - Test Fold: 5
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run082",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_SRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run082")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet3",
    weights_name="Run082_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run082_class_dice_resized.csv")
class_df
# Out:
#                                  AllSlices  \
# 0  0.8516556702408561 (0.3267044743863269)
#
#                             SlicesWithFluid  \
# 0  0.8365938945575896 (0.13893324336301516)
#
#                         SlicesWithoutFluid
# 0  0.8546861564918314 (0.3525685934984076)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run082_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_SRF
# 0      Cirrus  0.7895359823014587 (0.38359872555978236)
# 1  Spectralis  0.8425734909812026 (0.31379517008038516)
# 2      Topcon  0.9336512448498979 (0.22126391198251727)

# %% [markdown]
# Compare Folds Results

# %%
from test_model import folds_results

folds_results(first_run_name="Run079", iteration=23, k=5, resized_images=True, binary_segmentation=True)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration23_vendors_results_resized.csv")
vendor_df
# Out:
#       vendors     dice_SRF
# 0      Cirrus  0.76 (0.10)
# 1  Spectralis  0.85 (0.06)
# 2      Topcon  0.90 (0.02)

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration23_classes_results_resized.csv")
class_df
# Out:
#      AllSlices SlicesWithFluid SlicesWithoutFluid
# 0  0.82 (0.05)     0.79 (0.05)        0.83 (0.05)

# %% [markdown]
# ## Final Testing <a id="finaltesting"></a>

# %%
from test_model import test_model

test_model(
    fold_test=1,
    model_name="UNet3",
    weights_name="Run0XX_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False,
    resize_images=True,
    final_test=True
)

# %%
from pandas import read_csv

class_df = read_csv("results\\Run0XX_class_dice_resized_final.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run0XX_vendor_dice_resized_final.csv")
vendor_df
