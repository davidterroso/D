# %% [markdown]
# # SRF U-Net Runs

# %% [markdown]
# ## Results & Logs
#
# To see logs and results of this run please check the folders in [this commit](https://github.com/davidterroso/D/commit/d131a81f6bf609ba79b8429852bdf67713d3f14a) and in [this commit](https://github.com/davidterroso/D/commit/40c8b3545772b739a4cb3a4c3e5b51c13bc12ea9).

# %% [markdown]
# ## Table of Contents
# * [Iteration 20](#iteration20)
# * [Iteration 23](#iteration23)
# * [Final Testing](#finaltesting)
# * [Iteration 27](#iteration27)
# * [Final Testing - Relative Distance Maps](#finaltestingrdm)
# * [Iteration 30 - Different Loss](#iteration30)
# * [Iteration 33](#iteration33)

# %% [markdown]
# ## Iteration 20 <a id="iteration20"></a>

# %% [markdown]
# *Run 067*
# - Train Folds: 3, 4, 5
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run067",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Training

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run067")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet3",
    weights_name="Run067_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run067_class_dice_resized.csv")
class_df
# Out:
#                                  AllSlices  \
# 0  0.899402646606387 (0.24408986437660005)
#
#                            SlicesWithFluid  \
# 0  0.7735787513576875 (0.2096124479051313)
#
#                          SlicesWithoutFluid
# 0  0.9381746810598626 (0.24095627452828336)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run067_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_SRF
# 0      Cirrus  0.8662717961007729 (0.26318210091635197)
# 1  Spectralis   0.8818559201700347 (0.2800857328211226)
# 2      Topcon    0.9563282990628588 (0.175254068748992)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 068*
# - Train Folds: 2, 4, 5
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run068",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128),
    n_pos=12, 
    n_neg=0, 
    pos=1,
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run068")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet3",
    weights_name="Run068_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run068_class_dice_resized.csv")
class_df
# Out:
#                                  AllSlices  \
# 0  0.7047684122898277 (0.4122374996022832)
#
#                             SlicesWithFluid  \
# 0  0.6663206314766094 (0.21612272649852227)
#
#                         SlicesWithoutFluid
# 0  0.7154620311070449 (0.4514006404107886)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run068_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_SRF
# 0      Cirrus  0.5987811713013798 (0.43323402737729366)
# 1  Spectralis   0.7411239905016763 (0.4073732835515621)
# 2      Topcon   0.8198557512951083 (0.3497657517828466)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 069*
# - Train Folds: 2, 3, 5
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run069",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run069")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet3",
    weights_name="Run069_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run069_class_dice_resized.csv")
class_df
# Out:
#                                  AllSlices  \
# 0  0.8155054538094295 (0.3541680174421931)
#
#                             SlicesWithFluid  \
# 0  0.7278328678195932 (0.22507091331916065)
#
#                         SlicesWithoutFluid
# 0  0.833469387755102 (0.37270841770189517)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run069_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_SRF
# 0      Cirrus   0.7686545695585665 (0.4104089264879691)
# 1  Spectralis   0.8738106525674159 (0.2861670161341126)
# 2      Topcon  0.8445003709406592 (0.30336742226108016)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 070*
# - Train Folds: 2, 3, 4
# - Validation Fold: 5
# - Test Fold: 5
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run070",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run070")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet3",
    weights_name="Run070_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run070_class_dice_resized.csv")
class_df
# Out:
#                                   AllSlices  \
# 0  0.7229430738439198 (0.41973057868117647)
#
#                             SlicesWithFluid  \
# 0  0.7647498895724615 (0.18785975703595237)
#
#                          SlicesWithoutFluid
# 0  0.7145313843508169 (0.45183163246969926)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run070_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_SRF
# 0      Cirrus   0.6665748225990683 (0.4399989741800542)
# 1  Spectralis    0.7654751649316476 (0.379570574495685)
# 2      Topcon  0.7730511177505832 (0.40377977121935976)

# %% [markdown]
# Compare Folds Results

# %%
from test_model import folds_results

folds_results(first_run_name="Run067", iteration=20, k=5, resized_images=True, binary_segmentation=True)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration20_vendors_results_resized.csv")
vendor_df
# Out:
#       vendors     dice_SRF
# 0      Cirrus  0.73 (0.10)
# 1  Spectralis  0.82 (0.06)
# 2      Topcon  0.85 (0.07)

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration20_classes_results_resized.csv")
class_df
# Out:
#      AllSlices SlicesWithFluid SlicesWithoutFluid
# 0  0.79 (0.08)     0.73 (0.04)        0.80 (0.09)

# %% [markdown]
# ## Iteration 23 <a id="iteration23"></a>

# %% [markdown]
# *Run 079*
# - Train Folds: 3, 4, 5
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run079",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_SRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Training

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run079")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet3",
    weights_name="Run079_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF",
    split="competitive_fold_selection_SRF.csv"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run079_class_dice_resized.csv")
class_df
# Out:
#                                AllSlices  \
# 0  0.69273632269422 (0.4300231981328842)
#
#                             SlicesWithFluid  \
# 0  0.7683658839294596 (0.20257313967367724)
#
#                          SlicesWithoutFluid
# 0  0.6732673267326733 (0.46922980750994514)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run079_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_SRF
# 0      Cirrus   0.6342879142612219 (0.4505601938897673)
# 1  Spectralis   0.7907986870833805 (0.3662988925526527)
# 2      Topcon  0.7188724596508109 (0.42152832742549345)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 080*
# - Train Folds: 2, 4, 5
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run080",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_SRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128),
    n_pos=12, 
    n_neg=0, 
    pos=1,
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run080")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet3",
    weights_name="Run080_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF",
    split="competitive_fold_selection_SRF.csv"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run080_class_dice_resized.csv")
class_df
# Out:
#                                   AllSlices  \
# 0  0.7356578881379667 (0.37750981378691373)
#
#                            SlicesWithFluid  \
# 0  0.6863424687744244 (0.1938328771420877)
#
#                         SlicesWithoutFluid
# 0  0.7560728744939271 (0.4296667764173486)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run080_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_SRF
# 0      Cirrus  0.5904731340007856 (0.40525263020340563)
# 1  Spectralis      0.86420077827512 (0.307388314790763)
# 2      Topcon  0.8556290493961569 (0.30017462056296557)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 081*
# - Train Folds: 2, 3, 5
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run081",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_SRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run081")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet3",
    weights_name="Run081_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF",
    split="competitive_fold_selection_SRF.csv"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run081_class_dice_resized.csv")
class_df
# Out:
#                                   AllSlices  \
# 0  0.8187303523413169 (0.35939756049692834)
#
#                             SlicesWithFluid  \
# 0  0.6538952933292701 (0.27240511635196046)
#
#                          SlicesWithoutFluid
# 0  0.8426601784266018 (0.36426860831738933)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run081_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_SRF
# 0      Cirrus   0.8206389735389166 (0.3571209950031471)
# 1  Spectralis    0.6942533037948365 (0.408930042902121)
# 2      Topcon  0.8589664355854943 (0.33408811544280365)

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 082*
# - Train Folds: 2, 3, 4
# - Validation Fold: 5
# - Test Fold: 5
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run082",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_SRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run082")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet3",
    weights_name="Run082_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF",
    split="competitive_fold_selection_SRF.csv"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run082_class_dice_resized.csv")
class_df
# Out:
#                                   AllSlices  \
# 0  0.6869326966280369 (0.43293110142825975)
#
#                             SlicesWithFluid  \
# 0  0.6927728261544438 (0.20898605937162204)
#
#                         SlicesWithoutFluid
# 0  0.6857876712328768 (0.4644002456130985)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run082_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_SRF
# 0      Cirrus  0.48679541700985285 (0.4738736645773951)
# 1  Spectralis   0.8150064670300226 (0.3427690248597998)
# 2      Topcon   0.8758189958607545 (0.2852238046226774)

# %% [markdown]
# Compare Folds Results

# %%
from test_model import folds_results

folds_results(first_run_name="Run079", iteration=23, k=5, resized_images=True, binary_segmentation=True)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration23_vendors_results_resized.csv")
vendor_df
# Out:
#       vendors     dice_SRF
# 0      Cirrus  0.63 (0.12)
# 1  Spectralis  0.79 (0.06)
# 2      Topcon  0.83 (0.06)

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration23_classes_results_resized.csv")
class_df
# Out:
#      AllSlices SlicesWithFluid SlicesWithoutFluid
# 0  0.73 (0.05)     0.70 (0.04)        0.74 (0.07)

# %% [markdown]
# ## Final Testing <a id="finaltesting"></a>

# %%
from test_model import test_model

test_model(
    fold_test=1,
    model_name="UNet3",
    weights_name="Run0XX_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False,
    resize_images=True,
    final_test=True
)

# %%
from pandas import read_csv

class_df = read_csv("results\\Run0XX_class_dice_resized_final.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run0XX_vendor_dice_resized_final.csv")
vendor_df

# %% [markdown]
# ## Iteration 27 <a id="iteration27"></a>

# %% [markdown]
# *Run 095*
# - With relative distance maps
# - Train Folds: 3, 4, 5
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run095",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_SRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=2,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Training

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run095")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet3",
    weights_name="Run095_SRF_UNet3_best_model.pth",
    number_of_channels=2,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run095_class_dice_resized.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run095_vendor_dice_resized.csv")
vendor_df

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 096*
# - With relative distance maps
# - Train Folds: 2, 4, 5
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run096",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_SRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=2,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128),
    n_pos=12, 
    n_neg=0, 
    pos=1,
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run096")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet3",
    weights_name="Run096_SRF_UNet3_best_model.pth",
    number_of_channels=2,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run096_class_dice_resized.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run096_vendor_dice_resized.csv")
vendor_df

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 097*
# - With relative distance maps
# - Train Folds: 2, 3, 5
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run097",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_SRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=2,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run097")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet3",
    weights_name="Run097_SRF_UNet3_best_model.pth",
    number_of_channels=2,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run097_class_dice_resized.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run097_vendor_dice_resized.csv")
vendor_df

# %% [markdown]
# Measures to Prevent Running Out Of Memory Between Runs

# %% [markdown]
# Clear Cache

# %%
import torch
import warnings

warnings.simplefilter("ignore", FutureWarning)
torch.cuda.empty_cache()
torch.cuda.reset_max_memory_allocated()

# %% [markdown]
# Restart Kernel

# %%
import IPython

IPython.display.clear_output(wait=True)

# %% [markdown]
# *Run 098*
# - With relative distance maps
# - Train Folds: 2, 3, 4
# - Validation Fold: 5
# - Test Fold: 5
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run098",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_SRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=2,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run098")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet3",
    weights_name="Run098_SRF_UNet3_best_model.pth",
    number_of_channels=2,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run098_class_dice_resized.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run098_vendor_dice_resized.csv")
vendor_df

# %% [markdown]
# Compare Folds Results

# %%
from test_model import folds_results

folds_results(first_run_name="Run095", iteration=26, k=5, resized_images=True, binary_segmentation=True)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration26_vendors_results_resized.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration26_classes_results_resized.csv")
class_df

# %% [markdown]
# ## Final Testing - Relative Distance Maps <a id="finaltestingrdm"></a>

# %%
from test_model import test_model

test_model(
    fold_test=1,
    model_name="UNet3",
    weights_name="Run0XX_SRF_UNet3_best_model.pth",
    number_of_channels=2,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=False,
    resize_images=True,
    final_test=True
)

# %%
from pandas import read_csv

class_df = read_csv("results\\Run0XX_class_dice_resized_final.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run0XX_vendor_dice_resized_final.csv")
vendor_df

# %% [markdown]
# ## Iteration 30 - Different Split <a id="iteration30"></a>

# %% [markdown]
# *Run 108*
# - Train Folds: 2, 4, 5
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run108",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_SRF_1.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128),
    n_pos=12, 
    n_neg=0, 
    pos=1,
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)
# Out:
# Training on cuda.
# INFO: Network
# 	1 input channels
# 	2 output channels (classes)
#
# INFO: Starting training:
#         Epochs:          200
#         Batch size:      32
#         Learning rate:   2e-05
#         Device:          cuda
#         Mixed Precision: True
#         Seed:            None
# Train Images: 28994 | Validation Images: 10227
# Loading Training Data.
# Loading Validation Data.
# Data loading took 0.0 seconds.
# Training Epoch 1
# Epoch 1/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 1
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.5481019536033273
# Model saved.
# Training Epoch 2
# Epoch 2/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 2
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.5638296935707331
# Training Epoch 3
# Epoch 3/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 3
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4816753877326846
# Model saved.
# Training Epoch 4
# Epoch 4/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 4
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4655678605195135
# Model saved.
# Training Epoch 5
# Epoch 5/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 5
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4450927464291453
# Model saved.
# Training Epoch 6
# Epoch 6/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 6
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.5807612152770162
# Training Epoch 7
# Epoch 7/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 7
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.45258937212638556
# Training Epoch 8
# Epoch 8/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 8
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.47120365547016263
# Training Epoch 9
# Epoch 9/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 9
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4689173001796007
# Training Epoch 10
# Epoch 10/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 10
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.46731274167541414
# Training Epoch 11
# Epoch 11/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 11
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.45861588704865425
# Training Epoch 12
# Epoch 12/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 12
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.38315508104860785
# Model saved.
# Training Epoch 13
# Epoch 13/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 13
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.42951282060239465
# Training Epoch 14
# Epoch 14/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 14
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.44319704906083646
# Training Epoch 15
# Epoch 15/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 15
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3888596856268123
# Training Epoch 16
# Epoch 16/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 16
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4176654726965353
# Training Epoch 17
# Epoch 17/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 17
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4440453671151772
# Training Epoch 18
# Epoch 18/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 18
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.38715957703534515
# Training Epoch 19
# Epoch 19/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 19
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.37293961273971943
# Model saved.
# Training Epoch 20
# Epoch 20/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 20
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4422860521590337
# Training Epoch 21
# Epoch 21/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 21
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.46687750855926424
# Training Epoch 22
# Epoch 22/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 22
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.41478663224261253
# Training Epoch 23
# Epoch 23/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 23
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.36316794296726584
# Model saved.
# Training Epoch 24
# Epoch 24/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 24
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3587186142569408
# Model saved.
# Training Epoch 25
# Epoch 25/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 25
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.40535264955833555
# Training Epoch 26
# Epoch 26/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 26
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4470645829336718
# Training Epoch 27
# Epoch 27/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 27
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3918621431221254
# Training Epoch 28
# Epoch 28/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 28
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3971482219174504
# Training Epoch 29
# Epoch 29/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 29
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3567350166034885
# Model saved.
# Training Epoch 30
# Epoch 30/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 30
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4309768678154796
# Training Epoch 31
# Epoch 31/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 31
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4197660562116653
# Training Epoch 32
# Epoch 32/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 32
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3541615947615355
# Model saved.
# Training Epoch 33
# Epoch 33/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 33
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4566307286964729
# Training Epoch 34
# Epoch 34/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 34
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4366048501105979
# Training Epoch 35
# Epoch 35/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 35
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3537753511220217
# Model saved.
# Training Epoch 36
# Epoch 36/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 36
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.37914000942837445
# Training Epoch 37
# Epoch 37/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 37
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4152190453140065
# Training Epoch 38
# Epoch 38/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 38
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.36877372519811613
# Training Epoch 39
# Epoch 39/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 39
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.36758402299601584
# Training Epoch 40
# Epoch 40/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 40
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.38658841925207527
# Training Epoch 41
# Epoch 41/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 41
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4510227780090645
# Training Epoch 42
# Epoch 42/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 42
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4244715050095692
# Training Epoch 43
# Epoch 43/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 43
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.37560308395186437
# Training Epoch 44
# Epoch 44/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 44
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.39550218303920703
# Training Epoch 45
# Epoch 45/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 45
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.32984985436778513
# Model saved.
# Training Epoch 46
# Epoch 46/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 46
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3883957851387095
# Training Epoch 47
# Epoch 47/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 47
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.45611886035185306
# Training Epoch 48
# Epoch 48/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 48
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.43026738248299806
# Training Epoch 49
# Epoch 49/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 49
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.39969054964603856
# Training Epoch 50
# Epoch 50/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 50
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.41750627546571195
# Training Epoch 51
# Epoch 51/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 51
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.409801044955384
# Training Epoch 52
# Epoch 52/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 52
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.37230331752216445
# Training Epoch 53
# Epoch 53/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 53
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.45199713488691484
# Training Epoch 54
# Epoch 54/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 54
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.46319814779562873
# Training Epoch 55
# Epoch 55/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 55
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.5105279179173522
# Training Epoch 56
# Epoch 56/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 56
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3499660776578821
# Training Epoch 57
# Epoch 57/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 57
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4346564360894263
# Training Epoch 58
# Epoch 58/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 58
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3705604066839442
# Training Epoch 59
# Epoch 59/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 59
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3335045787971467
# Training Epoch 60
# Epoch 60/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 60
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.334528656071052
# Training Epoch 61
# Epoch 61/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 61
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.421345802070573
# Training Epoch 62
# Epoch 62/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 62
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.37867460162378846
# Training Epoch 63
# Epoch 63/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 63
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3595717457821593
# Training Epoch 64
# Epoch 64/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 64
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4029202541918494
# Training Epoch 65
# Epoch 65/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 65
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.42561735736671835
# Training Epoch 66
# Epoch 66/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 66
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3791566093219444
# Training Epoch 67
# Epoch 67/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 67
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3941180664813146
# Training Epoch 68
# Epoch 68/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 68
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3887309864745475
# Training Epoch 69
# Epoch 69/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 69
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4155209488235414
# Training Epoch 70
# Epoch 70/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 70
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.44384304781560785
# Training Epoch 71
# Epoch 71/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 71
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3719357139663771
# Training Epoch 72
# Epoch 72/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 72
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.39485497889108956
# Training Epoch 73
# Epoch 73/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 73
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.45123579784994944
# Training Epoch 74
# Epoch 74/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 74
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.44575547756394374
# Training Epoch 75
# Epoch 75/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 75
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4039287859690376
# Training Epoch 76
# Epoch 76/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 76
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.39562686033314093
# Training Epoch 77
# Epoch 77/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 77
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4543107355479151
# Training Epoch 78
# Epoch 78/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 78
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3851150524802506
# Training Epoch 79
# Epoch 79/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 79
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3964501961017959
# Training Epoch 80
# Epoch 80/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 80
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.35348812232259663
# Training Epoch 81
# Epoch 81/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 81
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3681548944674432
# Training Epoch 82
# Epoch 82/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 82
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.45990698084933684
# Training Epoch 83
# Epoch 83/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 83
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3467808336718008
# Training Epoch 84
# Epoch 84/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 84
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.41015897010220215
# Training Epoch 85
# Epoch 85/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 85
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4518324919976294
# Training Epoch 86
# Epoch 86/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 86
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.37579253400908785
# Training Epoch 87
# Epoch 87/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 87
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.38767715647118167
# Training Epoch 88
# Epoch 88/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 88
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.36508808988146485
# Training Epoch 89
# Epoch 89/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 89
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.42882958251284437
# Training Epoch 90
# Epoch 90/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 90
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3718427164014429
# Training Epoch 91
# Epoch 91/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 91
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4196702559478581
# Training Epoch 92
# Epoch 92/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 92
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.42129944687476384
# Training Epoch 93
# Epoch 93/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 93
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.41434474705019964
# Training Epoch 94
# Epoch 94/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 94
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3682528417441063
# Training Epoch 95
# Epoch 95/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 95
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.40435528800007886
# Training Epoch 96
# Epoch 96/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 96
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3993204098078422
# Training Epoch 97
# Epoch 97/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 97
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3576900065643713
# Training Epoch 98
# Epoch 98/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 98
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.45105447658570486
# Training Epoch 99
# Epoch 99/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 99
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.39667488626437264
# Training Epoch 100
# Epoch 100/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 100
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3464386918931268
# Training Epoch 101
# Epoch 101/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 101
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4030949223553762
# Training Epoch 102
# Epoch 102/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 102
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4361116520187352
# Training Epoch 103
# Epoch 103/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 103
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.42916596261784434
# Training Epoch 104
# Epoch 104/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 104
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4462097338604508
# Training Epoch 105
# Epoch 105/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 105
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4208392043481581
# Training Epoch 106
# Epoch 106/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 106
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.430552173149772
# Training Epoch 107
# Epoch 107/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 107
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.36824325134512037
# Training Epoch 108
# Epoch 108/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 108
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.39202739160973576
# Training Epoch 109
# Epoch 109/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 109
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4135418475430924
# Training Epoch 110
# Epoch 110/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 110
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4115697469096631
# Training Epoch 111
# Epoch 111/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 111
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4191900687874295
# Training Epoch 112
# Epoch 112/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 112
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4173122860607691
# Training Epoch 113
# Epoch 113/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 113
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.43447116076713427
# Training Epoch 114
# Epoch 114/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 114
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3928697173949331
# Training Epoch 115
# Epoch 115/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 115
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3987151020672172
# Training Epoch 116
# Epoch 116/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 116
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.44138046604348347
# Training Epoch 117
# Epoch 117/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 117
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3922147868201137
# Training Epoch 118
# Epoch 118/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 118
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.42357720298459756
# Training Epoch 119
# Epoch 119/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 119
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.40258341742446646
# Training Epoch 120
# Epoch 120/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 120
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4212568033137359
# Training Epoch 121
# Epoch 121/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 121
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4104477113345638
# Training Epoch 122
# Epoch 122/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 122
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.3987172288820148
# Training Epoch 123
# Epoch 123/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 123
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4109288971987553
# Training Epoch 124
# Epoch 124/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 124
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.37851948987226935
# Training Epoch 125
# Epoch 125/200:   0%|          | 0/28994 [00:00<?, ?img/s]
# Validating Epoch 125
# Validating Epoch:   0%|          | 0/10227 [00:00<?, ?img/s]
# INFO: Validation Mean Loss: 0.4081855824450031
# INFO: Early stopping triggered.

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run108")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet3",
    weights_name="Run108_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF",
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run108_class_dice_resized.csv")
class_df
# Out:
#                                  AllSlices  \
# 0  0.6127469969909172 (0.4497048588984991)
#
#                            SlicesWithFluid  \
# 0  0.744559703786282 (0.20215355821843975)
#
#                          SlicesWithoutFluid
# 0  0.5721295387634936 (0.49501292763663274)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run108_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_SRF
# 0      Cirrus  0.5089137028902769 (0.44368080835225726)
# 1  Spectralis   0.617130139105174 (0.45586704886505597)
# 2      Topcon   0.7586832434338119 (0.4135150941959075)

# %% [markdown]
# *Run 109*
# - Train Folds: 2, 4, 5
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run109",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_SRF_1.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128),
    n_pos=12, 
    n_neg=0, 
    pos=1,
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run109")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet3",
    weights_name="Run109_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run109_class_dice_resized.csv")
class_df
# Out:
#                                  AllSlices  \
# 0  0.8066639374280262 (0.3519451412477167)
#
#                             SlicesWithFluid  \
# 0  0.7793076335097124 (0.15551412715316493)
#
#                         SlicesWithoutFluid
# 0  0.8142726440988106 (0.3890645147779405)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run109_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_SRF
# 0      Cirrus  0.7426379900745814 (0.38342276956619414)
# 1  Spectralis    0.776015761068889 (0.3898575770615994)
# 2      Topcon  0.9013620028854348 (0.25962596651881287)

# %% [markdown]
# *Run 110*
# - Train Folds: 2, 3, 5
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run110",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_SRF_1.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run110")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet3",
    weights_name="Run110_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run110_class_dice_resized.csv")
class_df
# Out:
#                                  AllSlices  \
# 0  0.7805769009601456 (0.3859026161830681)
#
#                             SlicesWithFluid  \
# 0  0.8092888677975096 (0.14957803299298733)
#
#                          SlicesWithoutFluid
# 0  0.7746938775510204 (0.41795439266711853)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run110_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_SRF
# 0      Cirrus   0.7195846928982064 (0.4391827003628861)
# 1  Spectralis  0.8642314058177325 (0.29852667398880006)
# 2      Topcon  0.8159499169094488 (0.34139473031910206)

# %% [markdown]
# *Run 111*
# - Train Folds: 2, 3, 4
# - Validation Fold: 5
# - Test Fold: 5
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run111",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_SRF_1.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run111")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet3",
    weights_name="Run111_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run111_class_dice_resized.csv")
class_df
# Out:
#                                  AllSlices  \
# 0  0.8190296399717085 (0.3578641625803813)
#
#                            SlicesWithFluid  \
# 0  0.8255743890618666 (0.1524343172213064)
#
#                         SlicesWithoutFluid
# 0  0.8177128116938951 (0.3862471318779105)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run111_vendor_dice_resized.csv")
vendor_df
# Out:
#        Vendor                                  dice_SRF
# 0      Cirrus  0.7745966926217079 (0.39376932967477074)
# 1  Spectralis  0.8098976038548411 (0.34148354614244686)
# 2      Topcon   0.8789406461291946 (0.3068899255016519)

# %% [markdown]
# Compare Folds Results

# %%
from test_model import folds_results

folds_results(first_run_name="Run108", iteration=30, k=5, resized_images=True, binary_segmentation=True)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration30_vendors_results_resized.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration30_classes_results_resized.csv")
class_df

# %% [markdown]
# ## Iteration 33 <a id="iteration33"></a>

# %% [markdown]
# *Run 119*
# - Train Folds: 3, 4, 5
# - Validation Fold: 2
# - Test Fold: 2
# - Unused Fold: 1

# %%
from train import train_model

train_model(
    run_name="Run119",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_SRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=2,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Training

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run119")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=2,
    model_name="UNet3",
    weights_name="Run119_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF",
    split="competitive_fold_selection_SRF.csv"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run119_class_dice_resized.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run119_vendor_dice_resized.csv")
vendor_df

# %% [markdown]
# *Run 120*
# - Train Folds: 2, 4, 5
# - Validation Fold: 3
# - Test Fold: 3
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run120",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_SRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=3,
    tuning=True,
    patch_shape=(256,128),
    n_pos=12, 
    n_neg=0, 
    pos=1,
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run120")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=3,
    model_name="UNet3",
    weights_name="Run120_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF",
    split="competitive_fold_selection_SRF.csv"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run120_class_dice_resized.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run120_vendor_dice_resized.csv")
vendor_df

# %% [markdown]
# *Run 121*
# - Train Folds: 2, 3, 5
# - Validation Fold: 4
# - Test Fold: 4
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run121",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_SRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=4,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run121")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=4,
    model_name="UNet3",
    weights_name="Run121_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF",
    split="competitive_fold_selection_SRF.csv"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run121_class_dice_resized.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run121_vendor_dice_resized.csv")
vendor_df

# %% [markdown]
# *Run 122*
# - Train Folds: 2, 3, 4
# - Validation Fold: 5
# - Test Fold: 5
# - Unused Fold: 1

# %% [markdown]
# Training

# %%
from train import train_model

train_model(
    run_name="Run122",
    model_name="UNet3",
    device="GPU",
    split="competitive_fold_selection_SRF.csv",
    epochs=200,
    batch_size=32,
    learning_rate=2e-5,
    optimizer_name="Adam",
    momentum=0.999,
    weight_decay=0.0001,
    gradient_clipping=1.0,
    scheduler=False, 
    patch_type="vertical",
    number_of_classes=2,
    number_of_channels=1,
    fold_test=1,
    fold_val=0,
    tuning=True,
    patch_shape=(256,128), 
    n_pos=12, 
    n_neg=0, 
    pos=1, 
    neg=0,
    amp=True,
    assyncronous_patch_extraction=True,
    patch_dropping=True,
    drop_prob=0.75,
    patience=25,
    num_patches=7,
    patience_after_n=100,
    fluid="SRF"
)

# %% [markdown]
# Plotting Logs

# %%
from plot_logs import plot_logs

plot_logs(imgs_folder="unet3_srf_imgs", run_name="Run122")

# %% [markdown]
# Testing

# %%
from test_model import test_model

test_model(
    fold_test=0,
    model_name="UNet3",
    weights_name="Run122_SRF_UNet3_best_model.pth",
    number_of_channels=1,
    number_of_classes=2,
    device_name="GPU",
    batch_size=1,
    patch_type="vertical",
    save_images=True,
    resize_images=True,
    fluid="SRF",
    split="competitive_fold_selection_SRF.csv"
)

# %% [markdown]
# Show Test Results

# %%
from pandas import read_csv

class_df = read_csv("results\\Run122_class_dice_resized.csv")
class_df

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Run122_vendor_dice_resized.csv")
vendor_df

# %% [markdown]
# Compare Folds Results

# %%
from test_model import folds_results

folds_results(first_run_name="Run119", iteration=32, k=5, resized_images=True, binary_segmentation=True)

# %%
from pandas import read_csv

vendor_df = read_csv("results\\Iteration32_vendors_results_resized.csv")
vendor_df

# %%
from pandas import read_csv

class_df = read_csv("results\\Iteration32_classes_results_resized.csv")
class_df
